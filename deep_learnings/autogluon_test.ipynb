# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
import pandas as pd
# Out:
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_csv('../raw_data/train.csv')

# %%
data = data.drop(['id'], axis=1)
data['location'] = list(zip(data['latitude'], data['longitude']))
data = data.drop(['latitude', 'longitude'], axis=1)

# %%
all_data = TabularDataset(data)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
predictor = TabularPredictor(label='price').fit(train_data=train_data)
predictions = predictor.predict(test_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231206_002032"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20231206_002032"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.7
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 23.1.0: Mon Oct  9 21:27:24 PDT 2023; root:xnu-10002.41.9~6/RELEASE_ARM64_T6000
# CPU Count:          10
# Memory Avail:       5.14 GB / 32.00 GB (16.0%)
# Disk Space Avail:   347.17 GB / 926.35 GB (37.5%)
# ===================================================
# Train Data Rows:    12352
# Train Data Columns: 45
# Label Column:       price
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == float, but few unique label-values observed and label-values can be converted to int).
# 	6 unique label values:  [5.0, 1.0, 2.0, 3.0, 0.0, 4.0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 6
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5292.68 MB
# 	Train Data (Original)  Memory Usage: 39.83 MB (0.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 6 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['name', 'description', 'property_type', 'amenities']
# 			CountVectorizer fit with vocabulary size = 10000
# 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# 		Reducing Vectorizer vocab size from 10000 to 6046 to avoid OOM error
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['scrape_id']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1): ['calendar_last_scraped']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', ['datetime_as_object']) : 1 | ['calendar_last_scraped']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      :  5 | ['host_listings_count', 'host_total_listings_count', 'beds', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm']
# 		('int', [])                        : 19 | ['host_id', 'accommodates', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', ...]
# 		('object', [])                     : 13 | ['picture_url', 'host_name', 'host_is_superhost', 'host_verifications', 'host_has_profile_pic', ...]
# 		('object', ['datetime_as_object']) :  2 | ['last_scraped', 'host_since']
# 		('object', ['text'])               :  4 | ['name', 'description', 'property_type', 'amenities']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :    9 | ['picture_url', 'host_name', 'host_is_superhost', 'host_verifications', 'neighbourhood_cleansed', ...]
# 		('category', ['text_as_category'])  :    4 | ['name', 'description', 'property_type', 'amenities']
# 		('float', [])                       :    5 | ['host_listings_count', 'host_total_listings_count', 'beds', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm']
# 		('int', [])                         :   19 | ['host_id', 'accommodates', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', ...]
# 		('int', ['binned', 'text_special']) :   62 | ['name.char_count', 'name.word_count', 'name.capital_ratio', 'name.lower_ratio', 'name.digit_ratio', ...]
# 		('int', ['bool'])                   :    5 | ['last_scraped', 'host_has_profile_pic', 'host_identity_verified', 'has_availability', 'instant_bookable']
# 		('int', ['datetime_as_int'])        :    5 | ['host_since', 'host_since.year', 'host_since.month', 'host_since.day', 'host_since.dayofweek']
# 		('int', ['text_ngram'])             : 5042 | ['__nlp__.000', '__nlp__.10', '__nlp__.10 min', '__nlp__.10 minute', '__nlp__.10 minutes', ...]
# 	51.5s = Fit runtime
# 	43 features in original data used to generate 5151 features in processed data.
# 	Train Data (Processed) Memory Usage: 122.53 MB (2.4% of available memory)
# Data preprocessing and feature engineering runtime = 52.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 11116, Val Rows: 1236
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 0.825 GB out of 5.235 GB available memory (15.749%)... (20.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.10 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Exception caused KNeighborsUnif to fail during training... Skipping this model.
# 		'NoneType' object has no attribute 'split'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1839, in _train_and_save
#     y_pred_proba_val = model.predict_proba(X_val)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 949, in predict_proba
#     y_pred_proba = self._predict_proba(X=X, **kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 991, in _predict_proba
#     y_pred_proba = self.model.predict_proba(X)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py", line 822, in kneighbors
#     results = ArgKmin.compute(
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py", line 271, in compute
#     return ArgKmin32.compute(
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 575, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin32.compute
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 74, in threadpool_limits
#     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 171, in __init__
#     self._original_info = self._set_threadpool_limits()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 268, in _set_threadpool_limits
#     modules = _ThreadpoolInfo(prefixes=self._prefixes,
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 340, in __init__
#     self._load_modules()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 371, in _load_modules
#     self._find_modules_with_dyld()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 428, in _find_modules_with_dyld
#     self._make_module_from_path(filepath)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Fitting model: KNeighborsDist ...
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 0.825 GB out of 5.105 GB available memory (16.151%)... (20.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.13 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Warning: Exception caused KNeighborsDist to fail during training... Skipping this model.
# 		'NoneType' object has no attribute 'split'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1839, in _train_and_save
#     y_pred_proba_val = model.predict_proba(X_val)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 949, in predict_proba
#     y_pred_proba = self._predict_proba(X=X, **kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 991, in _predict_proba
#     y_pred_proba = self.model.predict_proba(X)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py", line 358, in predict_proba
#     neigh_dist, neigh_ind = self.kneighbors(X)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py", line 822, in kneighbors
#     results = ArgKmin.compute(
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py", line 271, in compute
#     return ArgKmin32.compute(
#   File "sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx", line 575, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin32.compute
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 74, in threadpool_limits
#     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 171, in __init__
#     self._original_info = self._set_threadpool_limits()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 268, in _set_threadpool_limits
#     modules = _ThreadpoolInfo(prefixes=self._prefixes,
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 340, in __init__
#     self._load_modules()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 371, in _load_modules
#     self._find_modules_with_dyld()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 428, in _find_modules_with_dyld
#     self._make_module_from_path(filepath)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# Fitting model: NeuralNetFastAI ...
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# No improvement since epoch 6: early stopping
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	0.5413	 = Validation score   (accuracy)
# 	12.7s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1817, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1763, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/common/utils/try_import.py", line 82, in try_import_lightgbm
#     import lightgbm
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py", line 21, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, pd_CategoricalDtype, pd_DataFrame, pd_Series
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/lightgbm/compat.py", line 145, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1817, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1763, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 854, in fit
#     out = self._fit(**kwargs)
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 98, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/common/utils/try_import.py", line 82, in try_import_lightgbm
#     import lightgbm
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py", line 21, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, pd_CategoricalDtype, pd_DataFrame, pd_Series
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/lightgbm/compat.py", line 145, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "/Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/dask/dataframe/accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: RandomForestGini ...
# 	0.5332	 = Validation score   (accuracy)
# 	7.34s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.5364	 = Validation score   (accuracy)
# 	6.95s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost ...
# 	Many features detected (5151), dynamically setting 'colsample_bylevel' to 0.19413706076490003 to speed up training (Default = 1).
# 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters.
# 	0.5769	 = Validation score   (accuracy)
# 	175.44s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.5283	 = Validation score   (accuracy)
# 	7.06s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.5388	 = Validation score   (accuracy)
# 	6.41s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.5728	 = Validation score   (accuracy)
# 	57.71s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.5405	 = Validation score   (accuracy)
# 	15.94s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	Warning: Not enough memory to safely train model. Estimated to require 4.787 GB out of 4.650 GB available memory (102.950%)... (90.000% of avail memory is the max safe size)
# 	To force training the model, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.19 to avoid the error)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Not enough memory to train LightGBMLarge... Skipping this model.
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'CatBoost': 0.4, 'NeuralNetFastAI': 0.2, 'RandomForestGini': 0.2, 'XGBoost': 0.2}
# 	0.5979	 = Validation score   (accuracy)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 358.52s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231206_002032")
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
#                  model  score_test  score_val eval_metric  pred_time_test  \
# 0  WeightedEnsemble_L2    0.591130   0.597896    accuracy        1.020477
# 1             CatBoost    0.579152   0.576861    accuracy        0.257505
# 2              XGBoost    0.570735   0.572816    accuracy        0.513522
# 3     RandomForestGini    0.547103   0.533172    accuracy        0.195808
# 4     RandomForestEntr    0.542247   0.536408    accuracy        0.167603
# 5       ExtraTreesGini    0.533182   0.528317    accuracy        0.154657
# 6       ExtraTreesEntr    0.532535   0.538835    accuracy        0.172958
# 7       NeuralNetTorch    0.526060   0.540453    accuracy        0.056137
# 8      NeuralNetFastAI    0.515053   0.541262    accuracy        0.051658
#
#    pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.482825  253.484287                 0.001984                0.000457
# 1       0.220944  175.438202                 0.257505                0.220944
# 2       0.163567   57.714728                 0.513522                0.163567
# 3       0.069808    7.340113                 0.195808                0.069808
# 4       0.074251    6.954784                 0.167603                0.074251
# 5       0.074394    7.055438                 0.154657                0.074394
# 6       0.074321    6.406442                 0.172958                0.074321
# 7       0.031999   15.940697                 0.056137                0.031999
# 8       0.028049   12.702626                 0.051658                0.028049
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.288619            2       True          9
# 1         175.438202            1       True          4
# 2          57.714728            1       True          7
# 3           7.340113            1       True          2
# 4           6.954784            1       True          3
# 5           7.055438            1       True          5
# 6           6.406442            1       True          6
# 7          15.940697            1       True          8
# 8          12.702626            1       True          1

# %%
predictor.fit_summary(show_plot=True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                  model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2   0.597896    accuracy       0.482825  253.484287                0.000457           0.288619            2       True          9
# 1             CatBoost   0.576861    accuracy       0.220944  175.438202                0.220944         175.438202            1       True          4
# 2              XGBoost   0.572816    accuracy       0.163567   57.714728                0.163567          57.714728            1       True          7
# 3      NeuralNetFastAI   0.541262    accuracy       0.028049   12.702626                0.028049          12.702626            1       True          1
# 4       NeuralNetTorch   0.540453    accuracy       0.031999   15.940697                0.031999          15.940697            1       True          8
# 5       ExtraTreesEntr   0.538835    accuracy       0.074321    6.406442                0.074321           6.406442            1       True          6
# 6     RandomForestEntr   0.536408    accuracy       0.074251    6.954784                0.074251           6.954784            1       True          3
# 7     RandomForestGini   0.533172    accuracy       0.069808    7.340113                0.069808           7.340113            1       True          2
# 8       ExtraTreesGini   0.528317    accuracy       0.074394    7.055438                0.074394           7.055438            1       True          5
# Number of models trained: 9
# Types of models trained:
# {'RFModel', 'CatBoostModel', 'TabularNeuralNetTorchModel', 'XTModel', 'XGBoostModel', 'NNFastAiTabularModel', 'WeightedEnsembleModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])                    :    9 | ['picture_url', 'host_name', 'host_is_superhost', 'host_verifications', 'neighbourhood_cleansed', ...]
# ('category', ['text_as_category'])  :    4 | ['name', 'description', 'property_type', 'amenities']
# ('float', [])                       :    5 | ['host_listings_count', 'host_total_listings_count', 'beds', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm']
# ('int', [])                         :   19 | ['host_id', 'accommodates', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', ...]
# ('int', ['binned', 'text_special']) :   62 | ['name.char_count', 'name.word_count', 'name.capital_ratio', 'name.lower_ratio', 'name.digit_ratio', ...]
# ('int', ['bool'])                   :    5 | ['last_scraped', 'host_has_profile_pic', 'host_identity_verified', 'has_availability', 'instant_bookable']
# ('int', ['datetime_as_int'])        :    5 | ['host_since', 'host_since.year', 'host_since.month', 'host_since.day', 'host_since.dayofweek']
# ('int', ['text_ngram'])             : 5042 | ['__nlp__.000', '__nlp__.10', '__nlp__.10 min', '__nlp__.10 minute', '__nlp__.10 minutes', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20231206_002032SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'NeuralNetFastAI': 'NNFastAiTabularModel',
#   'RandomForestGini': 'RFModel',
#   'RandomForestEntr': 'RFModel',
#   'CatBoost': 'CatBoostModel',
#   'ExtraTreesGini': 'XTModel',
#   'ExtraTreesEntr': 'XTModel',
#   'XGBoost': 'XGBoostModel',
#   'NeuralNetTorch': 'TabularNeuralNetTorchModel',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'NeuralNetFastAI': 0.5412621359223301,
#   'RandomForestGini': 0.5331715210355987,
#   'RandomForestEntr': 0.5364077669902912,
#   'CatBoost': 0.5768608414239482,
#   'ExtraTreesGini': 0.5283171521035599,
#   'ExtraTreesEntr': 0.5388349514563107,
#   'XGBoost': 0.5728155339805825,
#   'NeuralNetTorch': 0.540453074433657,
#   'WeightedEnsemble_L2': 0.5978964401294499},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'NeuralNetFastAI': ['NeuralNetFastAI'],
#   'RandomForestGini': ['RandomForestGini'],
#   'RandomForestEntr': ['RandomForestEntr'],
#   'CatBoost': ['CatBoost'],
#   'ExtraTreesGini': ['ExtraTreesGini'],
#   'ExtraTreesEntr': ['ExtraTreesEntr'],
#   'XGBoost': ['XGBoost'],
#   'NeuralNetTorch': ['NeuralNetTorch'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'NeuralNetFastAI': 12.70262598991394,
#   'RandomForestGini': 7.340112686157227,
#   'RandomForestEntr': 6.954784154891968,
#   'CatBoost': 175.4382016658783,
#   'ExtraTreesGini': 7.055437803268433,
#   'ExtraTreesEntr': 6.406441926956177,
#   'XGBoost': 57.71472787857056,
#   'NeuralNetTorch': 15.940697193145752,
#   'WeightedEnsemble_L2': 0.2886190414428711},
#  'model_pred_times': {'NeuralNetFastAI': 0.028048992156982422,
#   'RandomForestGini': 0.0698082447052002,
#   'RandomForestEntr': 0.07425093650817871,
#   'CatBoost': 0.22094416618347168,
#   'ExtraTreesGini': 0.07439422607421875,
#   'ExtraTreesEntr': 0.07432126998901367,
#   'XGBoost': 0.16356706619262695,
#   'NeuralNetTorch': 0.03199887275695801,
#   'WeightedEnsemble_L2': 0.00045680999755859375},
#  'num_bag_folds': 0,
#  'max_stack_level': 2,
#  'num_classes': 6,
#  'model_hyperparams': {'NeuralNetFastAI': {'layers': None,
#    'emb_drop': 0.1,
#    'ps': 0.1,
#    'bs': 'auto',
#    'lr': 0.01,
#    'epochs': 'auto',
#    'early.stopping.min_delta': 0.0001,
#    'early.stopping.patience': 20,
#    'smoothing': 0.0},
#   'RandomForestGini': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'RandomForestEntr': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'CatBoost': {'iterations': 10000,
#    'learning_rate': 0.05,
#    'random_seed': 0,
#    'allow_writing_files': False,
#    'eval_metric': 'Accuracy'},
#   'ExtraTreesGini': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'ExtraTreesEntr': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'XGBoost': {'n_estimators': 10000,
#    'learning_rate': 0.1,
#    'n_jobs': -1,
#    'proc.max_category_levels': 100,
#    'objective': 'multi:softprob',
#    'booster': 'gbtree',
#    'num_class': 6},
#   'NeuralNetTorch': {'num_epochs': 500,
#    'epochs_wo_improve': 20,
#    'activation': 'relu',
#    'embedding_size_factor': 1.0,
#    'embed_exponent': 0.56,
#    'max_embedding_dim': 100,
#    'y_range': None,
#    'y_range_extend': 0.05,
#    'dropout_prob': 0.1,
#    'optimizer': 'adam',
#    'learning_rate': 0.0003,
#    'weight_decay': 1e-06,
#    'proc.embed_min_categories': 4,
#    'proc.impute_strategy': 'median',
#    'proc.max_category_levels': 100,
#    'proc.skew_threshold': 0.99,
#    'use_ngram_features': False,
#    'num_layers': 4,
#    'hidden_size': 128,
#    'max_batch_size': 512,
#    'use_batchnorm': False,
#    'loss_function': 'auto'},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                  model  score_val eval_metric  pred_time_val    fit_time  \
#  0  WeightedEnsemble_L2   0.597896    accuracy       0.482825  253.484287
#  1             CatBoost   0.576861    accuracy       0.220944  175.438202
#  2              XGBoost   0.572816    accuracy       0.163567   57.714728
#  3      NeuralNetFastAI   0.541262    accuracy       0.028049   12.702626
#  4       NeuralNetTorch   0.540453    accuracy       0.031999   15.940697
#  5       ExtraTreesEntr   0.538835    accuracy       0.074321    6.406442
#  6     RandomForestEntr   0.536408    accuracy       0.074251    6.954784
#  7     RandomForestGini   0.533172    accuracy       0.069808    7.340113
#  8       ExtraTreesGini   0.528317    accuracy       0.074394    7.055438
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                0.000457           0.288619            2       True
#  1                0.220944         175.438202            1       True
#  2                0.163567          57.714728            1       True
#  3                0.028049          12.702626            1       True
#  4                0.031999          15.940697            1       True
#  5                0.074321           6.406442            1       True
#  6                0.074251           6.954784            1       True
#  7                0.069808           7.340113            1       True
#  8                0.074394           7.055438            1       True
#
#     fit_order
#  0          9
#  1          4
#  2          7
#  3          1
#  4          8
#  5          6
#  6          3
#  7          2
#  8          5  }

# %%
predictor.feature_importance(test_data)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['scrape_id', 'calendar_last_scraped']
# Computing feature importance via permutation shuffling for 43 features using 3089 rows with 5 shuffle sets...
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	661.94s	= Expected runtime (132.39s per shuffle set)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# /Users/xinyutian/opt/anaconda3/lib/python3.9/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py:200: FutureWarning: The 'downcast' keyword in fillna is deprecated and will be removed in a future version. Use res.infer_objects(copy=False) to infer non-object dtype, or pd.to_numeric with the 'downcast' keyword to downcast numeric results.
#   df = df.fillna(column_fills, inplace=False, downcast=False)
# 	519.38s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                 importance    stddev  \
# bathrooms_text                                4.305601e-02  0.006713
# amenities                                     4.247329e-02  0.003232
# neighbourhood_cleansed                        3.800583e-02  0.004156
# description                                   3.541599e-02  0.004430
# property_type                                 3.509226e-02  0.004353
# name                                          3.340887e-02  0.003075
# accommodates                                  2.227258e-02  0.004643
# host_name                                     1.463257e-02  0.003687
# calculated_host_listings_count_private_rooms  4.143736e-03  0.001609
# minimum_minimum_nights                        3.820006e-03  0.000532
# availability_365                              3.302039e-03  0.001198
# number_of_reviews_ltm                         3.237294e-03  0.001569
# host_since                                    2.978310e-03  0.002140
# minimum_nights                                2.460343e-03  0.001346
# availability_30                               2.395597e-03  0.001112
# neighbourhood_group_cleansed                  2.395597e-03  0.000875
# beds                                          1.683393e-03  0.001107
# room_type                                     1.553901e-03  0.001473
# maximum_minimum_nights                        1.489155e-03  0.001923
# has_availability                              1.424409e-03  0.000671
# host_listings_count                           1.359663e-03  0.001794
# minimum_maximum_nights                        1.294917e-03  0.000759
# last_scraped                                  1.230172e-03  0.000271
# host_identity_verified                        1.230172e-03  0.000898
# number_of_reviews_l30d                        1.100680e-03  0.001676
# instant_bookable                              1.035934e-03  0.000869
# number_of_reviews                             1.035934e-03  0.001508
# minimum_nights_avg_ntm                        7.122046e-04  0.001437
# maximum_nights_avg_ntm                        5.827129e-04  0.000422
# calculated_host_listings_count_shared_rooms   3.884752e-04  0.000271
# availability_60                               3.884752e-04  0.001343
# maximum_maximum_nights                        3.237294e-04  0.000606
# calculated_host_listings_count_entire_homes   1.942376e-04  0.001644
# calculated_host_listings_count                1.942376e-04  0.000987
# location                                      1.294917e-04  0.000177
# host_total_listings_count                     1.294917e-04  0.001112
# maximum_nights                                6.474587e-05  0.000579
# picture_url                                  -2.220446e-17  0.000229
# host_id                                      -2.589835e-04  0.000702
# host_is_superhost                            -3.884752e-04  0.000422
# host_has_profile_pic                         -5.179670e-04  0.000177
# host_verifications                           -7.769505e-04  0.001135
# availability_90                              -1.100680e-03  0.001112
#
#                                                p_value  n  p99_high   p99_low
# bathrooms_text                                0.000069  5  0.056878  0.029234
# amenities                                     0.000004  5  0.049129  0.035818
# neighbourhood_cleansed                        0.000017  5  0.046563  0.029449
# description                                   0.000029  5  0.044538  0.026294
# property_type                                 0.000028  5  0.044055  0.026130
# name                                          0.000009  5  0.039739  0.027078
# accommodates                                  0.000214  5  0.031833  0.012713
# host_name                                     0.000445  5  0.022224  0.007041
# calculated_host_listings_count_private_rooms  0.002255  5  0.007456  0.000831
# minimum_minimum_nights                        0.000044  5  0.004915  0.002725
# availability_365                              0.001760  5  0.005769  0.000835
# number_of_reviews_ltm                         0.004968  5  0.006469  0.000006
# host_since                                    0.017902  5  0.007385 -0.001428
# minimum_nights                                0.007513  5  0.005233 -0.000312
# availability_30                               0.004271  5  0.004685  0.000106
# neighbourhood_group_cleansed                  0.001801  5  0.004197  0.000595
# beds                                          0.013647  5  0.003963 -0.000597
# room_type                                     0.038871  5  0.004587 -0.001479
# maximum_minimum_nights                        0.079227  5  0.005449 -0.002471
# has_availability                              0.004503  5  0.002807  0.000042
# host_listings_count                           0.082662  5  0.005053 -0.002334
# minimum_maximum_nights                        0.009439  5  0.002858 -0.000268
# last_scraped                                  0.000265  5  0.001788  0.000672
# host_identity_verified                        0.018790  5  0.003080 -0.000619
# number_of_reviews_l30d                        0.107935  5  0.004551 -0.002350
# instant_bookable                              0.028000  5  0.002825 -0.000753
# number_of_reviews                             0.099665  5  0.004141 -0.002069
# minimum_nights_avg_ntm                        0.164933  5  0.003671 -0.002246
# maximum_nights_avg_ntm                        0.018341  5  0.001452 -0.000286
# calculated_host_listings_count_shared_rooms   0.016339  5  0.000946 -0.000169
# availability_60                               0.276445  5  0.003153 -0.002376
# maximum_maximum_nights                        0.149007  5  0.001571 -0.000923
# calculated_host_listings_count_entire_homes   0.402363  5  0.003580 -0.003191
# calculated_host_listings_count                0.341353  5  0.002227 -0.001839
# location                                      0.088904  5  0.000495 -0.000236
# host_total_listings_count                     0.403713  5  0.002419 -0.002160
# maximum_nights                                0.407451  5  0.001257 -0.001128
# picture_url                                   0.500000  5  0.000471 -0.000471
# host_id                                       0.772170  5  0.001186 -0.001704
# host_is_superhost                             0.945650  5  0.000481 -0.001258
# host_has_profile_pic                          0.998581  5 -0.000153 -0.000883
# host_verifications                            0.899643  5  0.001561 -0.003115
# availability_90                               0.954350  5  0.001189 -0.003390

# %%
predictor.info()
# Out:
# {'path': 'AutogluonModels/ag-20231206_002032',
#  'label': 'price',
#  'random_state': 0,
#  'version': '1.0.0',
#  'features': ['last_scraped',
#   'name',
#   'description',
#   'picture_url',
#   'host_id',
#   'host_name',
#   'host_since',
#   'host_is_superhost',
#   'host_listings_count',
#   'host_total_listings_count',
#   'host_verifications',
#   'host_has_profile_pic',
#   'host_identity_verified',
#   'neighbourhood_cleansed',
#   'neighbourhood_group_cleansed',
#   'property_type',
#   'room_type',
#   'accommodates',
#   'bathrooms_text',
#   'beds',
#   'amenities',
#   'minimum_nights',
#   'maximum_nights',
#   'minimum_minimum_nights',
#   'maximum_minimum_nights',
#   'minimum_maximum_nights',
#   'maximum_maximum_nights',
#   'minimum_nights_avg_ntm',
#   'maximum_nights_avg_ntm',
#   'has_availability',
#   'availability_30',
#   'availability_60',
#   'availability_90',
#   'availability_365',
#   'number_of_reviews',
#   'number_of_reviews_ltm',
#   'number_of_reviews_l30d',
#   'instant_bookable',
#   'calculated_host_listings_count',
#   'calculated_host_listings_count_entire_homes',
#   'calculated_host_listings_count_private_rooms',
#   'calculated_host_listings_count_shared_rooms',
#   'location'],
#  'feature_metadata_in': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x7f8bb868f5b0>,
#  'time_fit_preprocessing': 52.16085410118103,
#  'time_fit_training': 306.3628480434418,
#  'time_fit_total': 358.5237021446228,
#  'time_limit': None,
#  'time_train_start': 1701822084.572146,
#  'num_rows_train': 11116,
#  'num_cols_train': 5151,
#  'num_rows_val': 1236,
#  'num_classes': 6,
#  'problem_type': 'multiclass',
#  'eval_metric': 'accuracy',
#  'best_model': 'WeightedEnsemble_L2',
#  'best_model_score_val': 0.5978964401294499,
#  'best_model_stack_level': 2,
#  'num_models_trained': 9,
#  'num_bag_folds': 0,
#  'max_stack_level': 2,
#  'max_core_stack_level': 1,
#  'model_info': {'NeuralNetFastAI': {'name': 'NeuralNetFastAI',
#    'model_type': 'NNFastAiTabularModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 12.70262598991394,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.028048992156982422,
#    'val_score': 0.5412621359223301,
#    'hyperparameters': {'layers': None,
#     'emb_drop': 0.1,
#     'ps': 0.1,
#     'bs': 'auto',
#     'lr': 0.01,
#     'epochs': 'auto',
#     'early.stopping.min_delta': 0.0001,
#     'early.stopping.patience': 20,
#     'smoothing': 0.0},
#    'hyperparameters_fit': {'epochs': 30, 'best_epoch': 6},
#    'hyperparameters_nondefault': [],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': ['bool', 'int', 'float', 'category'],
#     'valid_special_types': None,
#     'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None},
#    'num_features': 105,
#    'features': ['last_scraped',
#     'host_id',
#     'host_listings_count',
#     'host_total_listings_count',
#     'host_has_profile_pic',
#     'host_identity_verified',
#     'accommodates',
#     'beds',
#     'minimum_nights',
#     'maximum_nights',
#     'minimum_minimum_nights',
#     'maximum_minimum_nights',
#     'minimum_maximum_nights',
#     'maximum_maximum_nights',
#     'minimum_nights_avg_ntm',
#     'maximum_nights_avg_ntm',
#     'has_availability',
#     'availability_30',
#     'availability_60',
#     'availability_90',
#     'availability_365',
#     'number_of_reviews',
#     'number_of_reviews_ltm',
#     'number_of_reviews_l30d',
#     'instant_bookable',
#     'calculated_host_listings_count',
#     'calculated_host_listings_count_entire_homes',
#     'calculated_host_listings_count_private_rooms',
#     'calculated_host_listings_count_shared_rooms',
#     'picture_url',
#     'host_name',
#     'host_is_superhost',
#     'host_verifications',
#     'neighbourhood_cleansed',
#     'neighbourhood_group_cleansed',
#     'room_type',
#     'bathrooms_text',
#     'location',
#     'host_since',
#     'host_since.year',
#     'host_since.month',
#     'host_since.day',
#     'host_since.dayofweek',
#     'name.char_count',
#     'name.word_count',
#     'name.capital_ratio',
#     'name.lower_ratio',
#     'name.digit_ratio',
#     'name.special_ratio',
#     'name.symbol_count..',
#     'name.symbol_ratio..',
#     'name.symbol_count. ',
#     'name.symbol_ratio. ',
#     'description.char_count',
#     'description.word_count',
#     'description.capital_ratio',
#     'description.lower_ratio',
#     'description.digit_ratio',
#     'description.special_ratio',
#     'description.symbol_count.!',
#     'description.symbol_ratio.!',
#     'description.symbol_count.?',
#     'description.symbol_ratio.?',
#     'description.symbol_count.%',
#     'description.symbol_ratio.%',
#     'description.symbol_count.$',
#     'description.symbol_ratio.$',
#     'description.symbol_count.*',
#     'description.symbol_ratio.*',
#     'description.symbol_count.&',
#     'description.symbol_ratio.&',
#     'description.symbol_count.#',
#     'description.symbol_ratio.#',
#     'description.symbol_count..',
#     'description.symbol_ratio..',
#     'description.symbol_count.:',
#     'description.symbol_ratio.:',
#     'description.symbol_count. ',
#     'description.symbol_ratio. ',
#     'description.symbol_count./',
#     'description.symbol_ratio./',
#     'description.symbol_count.;',
#     'description.symbol_ratio.;',
#     'description.symbol_count.-',
#     'description.symbol_ratio.-',
#     'property_type.char_count',
#     'property_type.word_count',
#     'property_type.capital_ratio',
#     'property_type.lower_ratio',
#     'property_type.special_ratio',
#     'property_type.symbol_ratio. ',
#     'amenities.char_count',
#     'amenities.word_count',
#     'amenities.capital_ratio',
#     'amenities.lower_ratio',
#     'amenities.digit_ratio',
#     'amenities.special_ratio',
#     'amenities.symbol_count.:',
#     'amenities.symbol_ratio.:',
#     'amenities.symbol_count. ',
#     'amenities.symbol_ratio. ',
#     'amenities.symbol_count./',
#     'amenities.symbol_ratio./',
#     'amenities.symbol_count.-',
#     'amenities.symbol_ratio.-'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x7f8be8e34b20>,
#    'memory_size': 1068889,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True},
#   'RandomForestGini': {'name': 'RandomForestGini',
#    'model_type': 'RFModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 7.340112686157227,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.0698082447052002,
#    'val_score': 0.5331715210355987,
#    'hyperparameters': {'n_estimators': 300,
#     'max_leaf_nodes': 15000,
#     'n_jobs': -1,
#     'random_state': 0,
#     'bootstrap': True,
#     'criterion': 'gini'},
#    'hyperparameters_fit': {'n_estimators': 300},
#    'hyperparameters_nondefault': ['criterion'],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': ['bool', 'int', 'float', 'category'],
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None},
#    'num_features': 5151,
#    'features': ['last_scraped',
#     'host_id',
#     'host_listings_count',
#     'host_total_listings_count',
#     'host_has_profile_pic',
#     'host_identity_verified',
#     'accommodates',
#     'beds',
#     'minimum_nights',
#     'maximum_nights',
#     'minimum_minimum_nights',
#     'maximum_minimum_nights',
#     'minimum_maximum_nights',
#     'maximum_maximum_nights',
#     'minimum_nights_avg_ntm',
#     'maximum_nights_avg_ntm',
#     'has_availability',
#     'availability_30',
#     'availability_60',
#     'availability_90',
#     'availability_365',
#     'number_of_reviews',
#     'number_of_reviews_ltm',
#     'number_of_reviews_l30d',
#     'instant_bookable',
#     'calculated_host_listings_count',
#     'calculated_host_listings_count_entire_homes',
#     'calculated_host_listings_count_private_rooms',
#     'calculated_host_listings_count_shared_rooms',
#     'name',
#     'description',
#     'picture_url',
#     'host_name',
#     'host_is_superhost',
#     'host_verifications',
#     'neighbourhood_cleansed',
#     'neighbourhood_group_cleansed',
#     'property_type',
#     'room_type',
#     'bathrooms_text',
#     'amenities',
#     'location',
#     'host_since',
#     'host_since.year',
#     'host_since.month',
#     'host_since.day',
#     'host_since.dayofweek',
#     'name.char_count',
#     'name.word_count',
#     'name.capital_ratio',
#     'name.lower_ratio',
#     'name.digit_ratio',
#     'name.special_ratio',
#     'name.symbol_count..',
#     'name.symbol_ratio..',
#     'name.symbol_count. ',
#     'name.symbol_ratio. ',
#     'description.char_count',
#     'description.word_count',
#     'description.capital_ratio',
#     'description.lower_ratio',
#     'description.digit_ratio',
#     'description.special_ratio',
#     'description.symbol_count.!',
#     'description.symbol_ratio.!',
#     'description.symbol_count.?',
#     'description.symbol_ratio.?',
#     'description.symbol_count.%',
#     'description.symbol_ratio.%',
#     'description.symbol_count.$',
#     'description.symbol_ratio.$',
#     'description.symbol_count.*',
#     'description.symbol_ratio.*',
#     'description.symbol_count.&',
#     'description.symbol_ratio.&',
#     'description.symbol_count.#',
#     'description.symbol_ratio.#',
#     'description.symbol_count..',
#     'description.symbol_ratio..',
#     'description.symbol_count.:',
#     'description.symbol_ratio.:',
#     'description.symbol_count. ',
#     'description.symbol_ratio. ',
#     'description.symbol_count./',
#     'description.symbol_ratio./',
#     'description.symbol_count.;',
#     'description.symbol_ratio.;',
#     'description.symbol_count.-',
#     'description.symbol_ratio.-',
#     'property_type.char_count',
#     'property_type.word_count',
#     'property_type.capital_ratio',
#     'property_type.lower_ratio',
#     'property_type.special_ratio',
#     'property_type.symbol_ratio. ',
#     'amenities.char_count',
#     'amenities.word_count',
#     'amenities.capital_ratio',
#     'amenities.lower_ratio',
#     'amenities.digit_ratio',
#     'amenities.special_ratio',
#     'amenities.symbol_count.:',
#     'amenities.symbol_ratio.:',
#     'amenities.symbol_count. ',
#     'amenities.symbol_ratio. ',
#     'amenities.symbol_count./',
#     'amenities.symbol_ratio./',
#     'amenities.symbol_count.-',
#     'amenities.symbol_ratio.-',
#     '__nlp__.000',
#     '__nlp__.10',
#     '__nlp__.10 min',
#     '__nlp__.10 minute',
#     '__nlp__.10 minutes',
#     '__nlp__.10 years',
#     '__nlp__.10 years old',
#     '__nlp__.100',
#     '__nlp__.101',
#     '__nlp__.11',
#     '__nlp__.12',
#     '__nlp__.14',
#     '__nlp__.15',
#     '__nlp__.15 min',
#     '__nlp__.15 minutes',
#     '__nlp__.16',
#     '__nlp__.19',
#     '__nlp__.1920',
#     '__nlp__.1st',
#     '__nlp__.20',
#     '__nlp__.20 min',
#     '__nlp__.20 minutes',
#     '__nlp__.2022',
#     '__nlp__.24',
#     '__nlp__.24 hour',
#     '__nlp__.24 hours',
#     '__nlp__.24 hours heated',
#     '__nlp__.25',
#     '__nlp__.2nd',
#     '__nlp__.2nd bedroom',
#     '__nlp__.2nd floor',
#     '__nlp__.30',
#     '__nlp__.30 minutes',
#     '__nlp__.31',
#     '__nlp__.32',
#     '__nlp__.360',
#     '__nlp__.3pm',
#     '__nlp__.3rd',
#     '__nlp__.40',
#     '__nlp__.405',
#     '__nlp__.42',
#     '__nlp__.45',
#     '__nlp__.4k',
#     '__nlp__.50',
#     '__nlp__.50 hdtv',
#     '__nlp__.50 hdtv with',
#     '__nlp__.500',
#     '__nlp__.55',
#     '__nlp__.55 hdtv',
#     '__nlp__.55 hdtv with',
#     '__nlp__.60',
#     '__nlp__.60 hdtv',
#     '__nlp__.60 hdtv with',
#     '__nlp__.65',
#     '__nlp__.65 hdtv',
#     '__nlp__.65 hdtv with',
#     '__nlp__.67',
#     '__nlp__.67 bedrooms',
#     '__nlp__.70',
#     '__nlp__.71',
#     '__nlp__.75',
#     '__nlp__.75 hdtv',
#     '__nlp__.80',
#     '__nlp__.82',
#     '__nlp__.83',
#     '__nlp__.85',
#     '__nlp__.86',
#     '__nlp__.86 bedrooms',
#     '__nlp__.87',
#     '__nlp__.88',
#     '__nlp__.88 bedrooms',
#     '__nlp__.89',
#     '__nlp__.90',
#     '__nlp__.90 bedrooms',
#     '__nlp__.91',
#     '__nlp__.92',
#     '__nlp__.93',
#     '__nlp__.93 bedrooms',
#     '__nlp__.93 bedrooms beds',
#     '__nlp__.94',
#     '__nlp__.94 bedrooms',
#     '__nlp__.95',
#     '__nlp__.96',
#     '__nlp__.97',
#     '__nlp__.98',
#     '__nlp__.99',
#     '__nlp__.abbot',
#     '__nlp__.abbot kinney',
#     '__nlp__.abbott',
#     '__nlp__.able',
#     '__nlp__.able to',
#     '__nlp__.about',
#     '__nlp__.above',
#     '__nlp__.absolutely',
#     '__nlp__.ac',
#     '__nlp__.ac split',
#     '__nlp__.ac unit',
#     '__nlp__.ac unit ceiling',
#     '__nlp__.ac unit free',
#     '__nlp__.access',
#     '__nlp__.access br',
#     '__nlp__.access br entire',
#     '__nlp__.access br guest',
#     '__nlp__.access br guests',
#     '__nlp__.access br the',
#     '__nlp__.access br you',
#     '__nlp__.access hair',
#     '__nlp__.access hangers',
#     '__nlp__.access the',
#     '__nlp__.access to',
#     '__nlp__.access to all',
#     '__nlp__.access to everything',
#     '__nlp__.access to public',
#     '__nlp__.access to the',
#     '__nlp__.access u2013',
#     '__nlp__.accessible',
#     '__nlp__.accommodate',
#     '__nlp__.accommodations',
#     '__nlp__.acre',
#     '__nlp__.across',
#     '__nlp__.across the',
#     '__nlp__.across the street',
#     '__nlp__.activities',
#     '__nlp__.added',
#     '__nlp__.addition',
#     '__nlp__.additional',
#     '__nlp__.address',
#     '__nlp__.address and',
#     '__nlp__.adjacent',
#     '__nlp__.adjacent to',
#     '__nlp__.adults',
#     '__nlp__.adventurers',
#     '__nlp__.after',
#     '__nlp__.ages',
#     '__nlp__.ages years',
#     '__nlp__.aid',
#     '__nlp__.aid kit',
#     '__nlp__.aid kit baking',
#     '__nlp__.aid kit dedicated',
#     '__nlp__.aid kit essentials',
#     '__nlp__.aid kit fire',
#     '__nlp__.aid kit indoor',
#     '__nlp__.aid kit mosquito',
#     '__nlp__.aid kit pets',
#     '__nlp__.aid kit private',
#     '__nlp__.aid kit stainless',
#     '__nlp__.air',
#     '__nlp__.air conditioning',
#     '__nlp__.air conditioning clothing',
#     '__nlp__.air conditioning coffee',
#     '__nlp__.air conditioning fire',
#     '__nlp__.air conditioning hot',
#     '__nlp__.air conditioning kitchen',
#     '__nlp__.air conditioning lock',
#     '__nlp__.air conditioning microwave',
#     '__nlp__.air conditioning outdoor',
#     '__nlp__.air conditioning pack',
#     '__nlp__.air conditioning pool',
#     '__nlp__.air conditioning room',
#     '__nlp__.air conditioning shared',
#     '__nlp__.air conditioning shower',
#     '__nlp__.air conditioning smoke',
#     '__nlp__.air conditioning smoking',
#     '__nlp__.air conditioning tv',
#     '__nlp__.air mattress',
#     '__nlp__.airbnb',
#     '__nlp__.airport',
#     '__nlp__.airy',
#     '__nlp__.al',
#     '__nlp__.alarm',
#     '__nlp__.alarm air',
#     '__nlp__.alarm board',
#     '__nlp__.alarm carbon',
#     '__nlp__.alarm dedicated',
#     '__nlp__.alarm dryer',
#     '__nlp__.alarm essentials',
#     '__nlp__.alarm essentials refrigerator',
#     '__nlp__.alarm fire',
#     '__nlp__.alarm first',
#     '__nlp__.alarm freezer',
#     '__nlp__.alarm freezer dining',
#     '__nlp__.alarm indoor',
#     '__nlp__.alarm iron',
#     '__nlp__.alarm iron air',
#     '__nlp__.alarm iron city',
#     '__nlp__.alarm iron dining',
#     '__nlp__.alarm iron first',
#     '__nlp__.alarm iron freezer',
#     '__nlp__.alarm iron gym',
#     '__nlp__.alarm iron host',
#     '__nlp__.alarm iron microwave',
#     '__nlp__.alarm iron stainless',
#     '__nlp__.alarm outdoor',
#     '__nlp__.alarm pets',
#     '__nlp__.alarm stainless',
#     '__nlp__.alarm valley',
#     '__nlp__.alhambra',
#     '__nlp__.all',
#     '__nlp__.all new',
#     '__nlp__.all of',
#     '__nlp__.all of the',
#     '__nlp__.all that',
#     '__nlp__.all the',
#     '__nlp__.all the amenities',
#     '__nlp__.all the best',
#     '__nlp__.all within',
#     '__nlp__.all year',
#     '__nlp__.all year open',
#     '__nlp__.all your',
#     '__nlp__.allow',
#     '__nlp__.allowed',
#     '__nlp__.allowed backyard',
#     '__nlp__.allowed backyard shampoo',
#     '__nlp__.allowed bathtub',
#     '__nlp__.allowed bathtub bed',
#     '__nlp__.allowed bathtub cleaning',
#     '__nlp__.allowed bathtub lockbox',
#     '__nlp__.allowed bed',
#     '__nlp__.allowed books',
#     '__nlp__.allowed br',
#     '__nlp__.allowed ceiling',
#     '__nlp__.allowed cleaning',
#     '__nlp__.allowed essentials',
#     '__nlp__.allowed essentials conditioner',
#     '__nlp__.allowed essentials refrigerator',
#     '__nlp__.allowed essentials tv',
#     '__nlp__.allowed free',
#     '__nlp__.allowed kitchen',
#     '__nlp__.allowed kitchen wifi',
#     '__nlp__.allowed lockbox',
#     '__nlp__.allowed microwave',
#     '__nlp__.allowed mountain',
#     '__nlp__.allowed refrigerator',
#     '__nlp__.allowed shampoo',
#     '__nlp__.allowed shampoo kitchen',
#     '__nlp__.allowed single',
#     '__nlp__.allowed smoke',
#     '__nlp__.allowed tv',
#     '__nlp__.allowed tv air',
#     '__nlp__.allowed washer',
#     '__nlp__.allowed washer backyard',
#     '__nlp__.allowed washer free',
#     '__nlp__.allowed washer shampoo',
#     '__nlp__.allowed washer single',
#     '__nlp__.allows',
#     '__nlp__.along',
#     '__nlp__.along the',
#     '__nlp__.along with',
#     '__nlp__.also',
#     '__nlp__.also has',
#     '__nlp__.also have',
#     '__nlp__.also offers',
#     '__nlp__.also offers in',
#     '__nlp__.altadena',
#     '__nlp__.always',
#     '__nlp__.always at',
#     '__nlp__.am',
#     '__nlp__.amazing',
#     '__nlp__.amazon',
#     '__nlp__.amazon prime',
#     '__nlp__.amazon prime video',
#     '__nlp__.ambiance',
#     '__nlp__.amenities',
#     '__nlp__.amenities and',
#     '__nlp__.amenities br',
#     '__nlp__.amenities br br',
#     '__nlp__.amenities include',
#     '__nlp__.amenities unique',
#     '__nlp__.amenities you',
#     '__nlp__.ample',
#     '__nlp__.an',
#     '__nlp__.an additional',
#     '__nlp__.an amazing',
#     '__nlp__.an extra',
#     '__nlp__.an office',
#     '__nlp__.an on',
#     '__nlp__.an on site',
#     '__nlp__.an open',
#     '__nlp__.an open floor',
#     '__nlp__.an outdoor',
#     '__nlp__.and',
#     '__nlp__.and 10',
#     '__nlp__.and 10 years',
#     '__nlp__.and air',
#     '__nlp__.and airy',
#     '__nlp__.and all',
#     '__nlp__.and all the',
#     '__nlp__.and an',
#     '__nlp__.and aux',
#     '__nlp__.and back',
#     '__nlp__.and backyard',
#     '__nlp__.and bars',
#     '__nlp__.and bath',
#     '__nlp__.and bathroom',
#     '__nlp__.and bathrooms',
#     '__nlp__.and bbq',
#     '__nlp__.and beautiful',
#     '__nlp__.and blankets',
#     '__nlp__.and blankets bbq',
#     '__nlp__.and blankets beach',
#     '__nlp__.and blankets clothing',
#     '__nlp__.and blankets coffee',
#     '__nlp__.and blankets hot',
#     '__nlp__.and blankets portable',
#     '__nlp__.and blankets safe',
#     '__nlp__.and breakfast',
#     '__nlp__.and bright',
#     '__nlp__.and business',
#     '__nlp__.and centrally',
#     '__nlp__.and clean',
#     '__nlp__.and close',
#     '__nlp__.and closet',
#     '__nlp__.and closet free',
#     '__nlp__.and coffee',
#     '__nlp__.and comfort',
#     '__nlp__.and comfortable',
#     '__nlp__.and convenience',
#     '__nlp__.and convenient',
#     '__nlp__.and cozy',
#     '__nlp__.and dining',
#     '__nlp__.and dining area',
#     '__nlp__.and downtown',
#     '__nlp__.and dresser',
#     '__nlp__.and dresser central',
#     '__nlp__.and dresser microwave',
#     '__nlp__.and dryer',
#     '__nlp__.and easy',
#     '__nlp__.and enjoy',
#     '__nlp__.and enjoy the',
#     '__nlp__.and entertainment',
#     '__nlp__.and entire',
#     '__nlp__.and family',
#     '__nlp__.and free',
#     '__nlp__.and friends',
#     '__nlp__.and full',
#     '__nlp__.and fully',
#     '__nlp__.and fully equipped',
#     '__nlp__.and great',
#     '__nlp__.and has',
#     '__nlp__.and high',
#     '__nlp__.and high speed',
#     '__nlp__.and hollywood',
#     '__nlp__.and hot',
#     '__nlp__.and hot tub',
#     '__nlp__.and in',
#     '__nlp__.and inviting',
#     '__nlp__.and is',
#     '__nlp__.and it',
#     '__nlp__.and jacuzzi',
#     '__nlp__.and just',
#     '__nlp__.and kitchen',
#     '__nlp__.and large',
#     '__nlp__.and laundry',
#     '__nlp__.and living',
#     '__nlp__.and living room',
#     '__nlp__.and lots',
#     '__nlp__.and luxurious',
#     '__nlp__.and many',
#     '__nlp__.and modern',
#     '__nlp__.and more',
#     '__nlp__.and more br',
#     '__nlp__.and much',
#     '__nlp__.and much more',
#     '__nlp__.and new',
#     '__nlp__.and one',
#     '__nlp__.and open',
#     '__nlp__.and or',
#     '__nlp__.and other',
#     '__nlp__.and other popular',
#     '__nlp__.and our',
#     '__nlp__.and outdoor',
#     '__nlp__.and parking',
#     '__nlp__.and patio',
#     '__nlp__.and peaceful',
#     '__nlp__.and plenty',
#     '__nlp__.and plenty of',
#     '__nlp__.and pool',
#     '__nlp__.and private',
#     '__nlp__.and queen',
#     '__nlp__.and quiet',
#     '__nlp__.and reading',
#     '__nlp__.and reading material',
#     '__nlp__.and relax',
#     '__nlp__.and relax in',
#     '__nlp__.and relaxation',
#     '__nlp__.and relaxing',
#     '__nlp__.and restaurants',
#     '__nlp__.and restaurants br',
#     '__nlp__.and safe',
#     '__nlp__.and santa',
#     '__nlp__.and santa monica',
#     '__nlp__.and serene',
#     '__nlp__.and shopping',
#     '__nlp__.and shops',
#     '__nlp__.and shower',
#     '__nlp__.and silverware',
#     '__nlp__.and silverware barbecue',
#     '__nlp__.and silverware beach',
#     '__nlp__.and silverware clothing',
#     '__nlp__.and silverware coffee',
#     '__nlp__.and silverware cooking',
#     '__nlp__.and silverware dishwasher',
#     '__nlp__.and silverware keypad',
#     '__nlp__.and silverware pack',
#     '__nlp__.and silverware private',
#     '__nlp__.and spa',
#     '__nlp__.and spacious',
#     '__nlp__.and start',
#     '__nlp__.and start living',
#     '__nlp__.and style',
#     '__nlp__.and stylish',
#     '__nlp__.and the',
#     '__nlp__.and there',
#     '__nlp__.and towels',
#     '__nlp__.and toys',
#     '__nlp__.and toys crib',
#     '__nlp__.and toys for',
#     '__nlp__.and toys hair',
#     '__nlp__.and tranquil',
#     '__nlp__.and two',
#     '__nlp__.and unit',
#     '__nlp__.and unwind',
#     '__nlp__.and very',
#     '__nlp__.and wardrobe',
#     '__nlp__.and we',
#     '__nlp__.and you',
#     '__nlp__.and your',
#     '__nlp__.angeles',
#     '__nlp__.angeles and',
#     '__nlp__.angeles bedroom',
#     '__nlp__.angeles bedroom bed',
#     '__nlp__.angeles bedroom beds',
#     '__nlp__.angeles bedrooms',
#     '__nlp__.angeles bedrooms beds',
#     '__nlp__.angeles br',
#     '__nlp__.angeles br br',
#     '__nlp__.angeles has',
#     '__nlp__.angeles new',
#     '__nlp__.angeles new bedroom',
#     '__nlp__.angeles new bedrooms',
#     '__nlp__.angeles studio',
#     '__nlp__.angeles with',
#     '__nlp__.angeles with this',
#     '__nlp__.another',
#     '__nlp__.any',
#     '__nlp__.any questions',
#     '__nlp__.anyone',
#     '__nlp__.anything',
#     '__nlp__.apartment',
#     '__nlp__.apartment also',
#     '__nlp__.apartment br',
#     '__nlp__.apartment carbon',
#     '__nlp__.apartment has',
#     '__nlp__.apartment in',
#     '__nlp__.apartment in los',
#     '__nlp__.apartment in the',
#     '__nlp__.apartment is',
#     '__nlp__.apartment laundry',
#     '__nlp__.apartment laundry br',
#     '__nlp__.apartment located',
#     '__nlp__.apartment with',
#     '__nlp__.apartment with its',
#     '__nlp__.apartment you',
#     '__nlp__.apartment you ll',
#     '__nlp__.apartments',
#     '__nlp__.apple',
#     '__nlp__.apple tv',
#     '__nlp__.apple tv disney',
#     '__nlp__.appliances',
#     '__nlp__.appliances and',
#     '__nlp__.appliances br',
#     '__nlp__.appointed',
#     '__nlp__.apt',
#     '__nlp__.arcadia',
#     '__nlp__.architectural',
#     '__nlp__.architecture',
#     '__nlp__.are',
#     '__nlp__.are all',
#     '__nlp__.are also',
#     '__nlp__.are available',
#     '__nlp__.are in',
#     '__nlp__.are just',
#     '__nlp__.are located',
#     '__nlp__.are not',
#     '__nlp__.are two',
#     '__nlp__.are welcome',
#     '__nlp__.area',
#     '__nlp__.area and',
#     '__nlp__.area br',
#     '__nlp__.area br br',
#     '__nlp__.area central',
#     '__nlp__.area fire',
#     '__nlp__.area fire extinguisher',
#     '__nlp__.area for',
#     '__nlp__.area gas',
#     '__nlp__.area gas stove',
#     '__nlp__.area hot',
#     '__nlp__.area hot water',
#     '__nlp__.area is',
#     '__nlp__.area kitchen',
#     '__nlp__.area kitchen security',
#     '__nlp__.area kitchen wifi',
#     '__nlp__.area of',
#     '__nlp__.area private',
#     '__nlp__.area room',
#     '__nlp__.area shared',
#     '__nlp__.area shared patio',
#     '__nlp__.area shower',
#     '__nlp__.area tv',
#     '__nlp__.area tv with',
#     '__nlp__.area with',
#     '__nlp__.areas',
#     '__nlp__.around',
#     '__nlp__.around the',
#     '__nlp__.arrival',
#     '__nlp__.art',
#     '__nlp__.arts',
#     '__nlp__.arts district',
#     '__nlp__.as',
#     '__nlp__.as the',
#     '__nlp__.as well',
#     '__nlp__.as well as',
#     '__nlp__.as you',
#     '__nlp__.ask',
#     '__nlp__.assigned',
#     '__nlp__.at',
#     '__nlp__.at home',
#     '__nlp__.at night',
#     '__nlp__.at our',
#     '__nlp__.at the',
#     '__nlp__.at this',
#     '__nlp__.at this centrally',
#     '__nlp__.at this peaceful',
#     '__nlp__.at time',
#     '__nlp__.at your',
#     '__nlp__.atmosphere',
#     '__nlp__.attached',
#     '__nlp__.attractions',
#     '__nlp__.attractions br',
#     '__nlp__.aux',
#     '__nlp__.availability',
#     '__nlp__.available',
#     '__nlp__.available all',
#     '__nlp__.available all year',
#     '__nlp__.available br',
#     '__nlp__.available br br',
#     '__nlp__.available during',
#     '__nlp__.available during stay',
#     '__nlp__.available for',
#     '__nlp__.available to',
#     '__nlp__.available upon',
#     '__nlp__.avalon',
#     '__nlp__.ave',
#     '__nlp__.avenue',
#     '__nlp__.awaits',
#     '__nlp__.away',
#     '__nlp__.away br',
#     '__nlp__.away br br',
#     '__nlp__.away from',
#     '__nlp__.away from home',
#     '__nlp__.away from rodeo',
#     '__nlp__.away from the',
#     '__nlp__.baby',
#     '__nlp__.baby bath',
#     '__nlp__.baby monitor',
#     '__nlp__.baby safety',
#     '__nlp__.babysitter',
#     '__nlp__.babysitter recommendations',
#     '__nlp__.babysitter recommendations central',
#     '__nlp__.back',
#     '__nlp__.back and',
#     '__nlp__.back and relax',
#     '__nlp__.back of',
#     '__nlp__.back patio',
#     '__nlp__.back yard',
#     '__nlp__.backyard',
#     '__nlp__.backyard and',
#     '__nlp__.backyard br',
#     '__nlp__.backyard is',
#     '__nlp__.backyard kitchen',
#     '__nlp__.backyard kitchen wifi',
#     '__nlp__.backyard shampoo',
#     '__nlp__.backyard shampoo kitchen',
#     '__nlp__.backyard u2013',
#     '__nlp__.backyard u2013 fully',
#     '__nlp__.backyard u2013 not',
#     '__nlp__.backyard with',
#     '__nlp__.baking',
#     '__nlp__.baking sheet',
#     '__nlp__.baking sheet essentials',
#     '__nlp__.baking sheet mountain',
#     '__nlp__.baking sheet pets',
#     '__nlp__.baking sheet record',
#     '__nlp__.baking sheet sun',
#     '__nlp__.balconies',
#     '__nlp__.balcony',
#     '__nlp__.balcony ac',
#     '__nlp__.balcony baking',
#     '__nlp__.balcony br',
#     '__nlp__.balcony central',
#     '__nlp__.balcony central air',
#     '__nlp__.balcony children',
#     '__nlp__.balcony dishes',
#     '__nlp__.balcony dishwasher',
#     '__nlp__.balcony dishwasher coffee',
#     '__nlp__.balcony essentials',
#     '__nlp__.balcony essentials conditioner',
#     '__nlp__.balcony essentials refrigerator',
#     '__nlp__.balcony free',
#     '__nlp__.balcony free parking',
#     '__nlp__.balcony pets',
#     '__nlp__.balcony shared',
#     '__nlp__.balcony shower',
#     '__nlp__.balcony sun',
#     '__nlp__.balcony wine',
#     '__nlp__.balcony with',
#     '__nlp__.bar',
#     '__nlp__.barbecue',
#     '__nlp__.barbecue utensils',
#     '__nlp__.barbecue utensils dishes',
#     '__nlp__.barbecue utensils dishwasher',
#     '__nlp__.bars',
#     '__nlp__.bars and',
#     '__nlp__.base',
#     '__nlp__.basic',
#     '__nlp__.basics',
#     '__nlp__.basics beach',
#     '__nlp__.basics clothing',
#     '__nlp__.basics free',
#     '__nlp__.basics free washer',
#     '__nlp__.basics hangers',
#     '__nlp__.basics hangers blender',
#     '__nlp__.basics hangers coffee',
#     '__nlp__.basics hangers elevator',
#     '__nlp__.basics hangers hair',
#     '__nlp__.basics hangers paid',
#     '__nlp__.basics hangers private',
#     '__nlp__.basics hangers self',
#     '__nlp__.basics hangers tv',
#     '__nlp__.basics keypad',
#     '__nlp__.basics keypad free',
#     '__nlp__.basics keypad hangers',
#     '__nlp__.basics pack',
#     '__nlp__.basics ping',
#     '__nlp__.basics private',
#     '__nlp__.basics private backyard',
#     '__nlp__.basics self',
#     '__nlp__.basics waterfront',
#     '__nlp__.basketball',
#     '__nlp__.bath',
#     '__nlp__.bath and',
#     '__nlp__.bath br',
#     '__nlp__.bath enjoy',
#     '__nlp__.bath home',
#     '__nlp__.bath located',
#     '__nlp__.bath private',
#     '__nlp__.bath the',
#     '__nlp__.bath this',
#     '__nlp__.bath this is',
#     '__nlp__.bath welcome',
#     '__nlp__.bath welcome to',
#     '__nlp__.bath with',
#     '__nlp__.bathroom',
#     '__nlp__.bathroom and',
#     '__nlp__.bathroom br',
#     '__nlp__.bathroom br br',
#     '__nlp__.bathroom has',
#     '__nlp__.bathroom home',
#     '__nlp__.bathroom is',
#     '__nlp__.bathroom the',
#     '__nlp__.bathroom with',
#     '__nlp__.bathrooms',
#     '__nlp__.bathrooms and',
#     '__nlp__.bathrooms br',
#     '__nlp__.baths',
#     '__nlp__.baths beautiful',
#     '__nlp__.baths enjoy',
#     '__nlp__.baths entire',
#     '__nlp__.baths located',
#     '__nlp__.baths our',
#     '__nlp__.baths relax',
#     '__nlp__.baths the',
#     '__nlp__.baths this',
#     '__nlp__.baths welcome',
#     '__nlp__.baths welcome to',
#     '__nlp__.bathtub',
#     '__nlp__.bathtub bed',
#     '__nlp__.bathtub cleaning',
#     '__nlp__.bathtub cleaning products',
#     '__nlp__.bathtub heating',
#     '__nlp__.bathtub heating split',
#     '__nlp__.bathtub lockbox',
#     '__nlp__.bathtub lockbox bed',
#     '__nlp__.bathtub lockbox cleaning',
#     '__nlp__.bathtub luggage',
#     '__nlp__.bathtub smoke',
#     '__nlp__.bay',
#     '__nlp__.bbq',
#     '__nlp__.bbq and',
#     '__nlp__.bbq area',
#     '__nlp__.bbq area br',
#     '__nlp__.bbq grill',
#     '__nlp__.bbq grill charcoal',
#     '__nlp__.bbq grill cleaning',
#     '__nlp__.bbq grill gas',
#     '__nlp__.bbq grill hot',
#     '__nlp__.bbq grill private',
#     '__nlp__.bbq grill smart',
#     '__nlp__.bbq grill washer',
#     '__nlp__.bbq grill wifi',
#     '__nlp__.be',
#     '__nlp__.be close',
#     '__nlp__.be given',
#     '__nlp__.be greeted',
#     '__nlp__.be used',
#     '__nlp__.beach',
#     '__nlp__.beach access',
#     '__nlp__.beach and',
#     '__nlp__.beach bedrooms',
#     '__nlp__.beach bedrooms beds',
#     '__nlp__.beach br',
#     '__nlp__.beach br br',
#     '__nlp__.beach essentials',
#     '__nlp__.beach essentials free',
#     '__nlp__.beach essentials washer',
#     '__nlp__.beach house',
#     '__nlp__.beach the',
#     '__nlp__.beach view',
#     '__nlp__.beach view ocean',
#     '__nlp__.beaches',
#     '__nlp__.beaches and',
#     '__nlp__.beachfront',
#     '__nlp__.beautiful',
#     '__nlp__.beautiful and',
#     '__nlp__.beautiful home',
#     '__nlp__.beautifully',
#     '__nlp__.beautifully designed',
#     '__nlp__.beauty',
#     '__nlp__.because',
#     '__nlp__.because of',
#     '__nlp__.bed',
#     '__nlp__.bed and',
#     '__nlp__.bed and breakfast',
#     '__nlp__.bed bath',
#     '__nlp__.bed bath this',
#     '__nlp__.bed bath welcome',
#     '__nlp__.bed baths',
#     '__nlp__.bed br',
#     '__nlp__.bed br br',
#     '__nlp__.bed in',
#     '__nlp__.bed in the',
#     '__nlp__.bed linens',
#     '__nlp__.bed linens indoor',
#     '__nlp__.bed linens smoke',
#     '__nlp__.bed private',
#     '__nlp__.bed private bath',
#     '__nlp__.bed shared',
#     '__nlp__.bed shared bath',
#     '__nlp__.bed shared baths',
#     '__nlp__.bed the',
#     '__nlp__.bed with',
#     '__nlp__.bedding',
#     '__nlp__.bedroom',
#     '__nlp__.bedroom and',
#     '__nlp__.bedroom and bathroom',
#     '__nlp__.bedroom apartment',
#     '__nlp__.bedroom apartment with',
#     '__nlp__.bedroom bath',
#     '__nlp__.bedroom bathroom',
#     '__nlp__.bedroom bathroom home',
#     '__nlp__.bedroom bed',
#     '__nlp__.bedroom bed bath',
#     '__nlp__.bedroom bed baths',
#     '__nlp__.bedroom bed private',
#     '__nlp__.bedroom bed shared',
#     '__nlp__.bedroom beds',
#     '__nlp__.bedroom beds bath',
#     '__nlp__.bedroom br',
#     '__nlp__.bedroom door',
#     '__nlp__.bedroom door microwave',
#     '__nlp__.bedroom has',
#     '__nlp__.bedroom has queen',
#     '__nlp__.bedroom home',
#     '__nlp__.bedroom house',
#     '__nlp__.bedroom is',
#     '__nlp__.bedroom one',
#     '__nlp__.bedroom queen',
#     '__nlp__.bedroom queen bed',
#     '__nlp__.bedroom suite',
#     '__nlp__.bedroom with',
#     '__nlp__.bedroom with queen',
#     '__nlp__.bedrooms',
#     '__nlp__.bedrooms and',
#     '__nlp__.bedrooms and bathrooms',
#     '__nlp__.bedrooms are',
#     '__nlp__.bedrooms bathrooms',
#     '__nlp__.bedrooms baths',
#     '__nlp__.bedrooms bed',
#     '__nlp__.bedrooms beds',
#     '__nlp__.bedrooms beds bath',
#     '__nlp__.bedrooms beds baths',
#     '__nlp__.bedrooms br',
#     '__nlp__.bedrooms have',
#     '__nlp__.bedrooms with',
#     '__nlp__.beds',
#     '__nlp__.beds and',
#     '__nlp__.beds bath',
#     '__nlp__.beds bath enjoy',
#     '__nlp__.beds bath this',
#     '__nlp__.beds bath welcome',
#     '__nlp__.beds baths',
#     '__nlp__.beds baths beautiful',
#     '__nlp__.beds baths enjoy',
#     '__nlp__.beds baths our',
#     '__nlp__.beds baths relax',
#     '__nlp__.beds baths the',
#     '__nlp__.beds baths this',
#     '__nlp__.beds baths welcome',
#     '__nlp__.beds br',
#     '__nlp__.beds private',
#     '__nlp__.beds private bath',
#     '__nlp__.beds shared',
#     '__nlp__.been',
#     '__nlp__.before',
#     '__nlp__.before booking',
#     '__nlp__.behind',
#     '__nlp__.being',
#     '__nlp__.belmont',
#     '__nlp__.below',
#     '__nlp__.best',
#     '__nlp__.best location',
#     '__nlp__.best of',
#     '__nlp__.best restaurants',
#     '__nlp__.better',
#     '__nlp__.between',
#     '__nlp__.beverly',
#     '__nlp__.beverly hills',
#     '__nlp__.beverly hills and',
#     '__nlp__.beverly hills bedroom',
#     '__nlp__.beverly hills bedrooms',
#     '__nlp__.beverly hills new',
#     '__nlp__.bidet',
#     '__nlp__.bidet dishes',
#     '__nlp__.bidet ethernet',
#     '__nlp__.big',
#     '__nlp__.bike',
#     '__nlp__.bikes',
#     '__nlp__.blankets',
#     '__nlp__.blankets safe hot',
#     '__nlp__.blend',
#     '__nlp__.blend of',
#     '__nlp__.blender',
#     '__nlp__.blender coffee',
#     '__nlp__.blender coffee outdoor',
#     '__nlp__.blender coffee self',
#     '__nlp__.blender coffee tv',
#     '__nlp__.blender self',
#     '__nlp__.block',
#     '__nlp__.block away',
#     '__nlp__.block from',
#     '__nlp__.blocks',
#     '__nlp__.blocks away',
#     '__nlp__.blocks from',
#     '__nlp__.blocks from the',
#     '__nlp__.blocks to',
#     '__nlp__.blue',
#     '__nlp__.blueground',
#     '__nlp__.blueground apartment',
#     '__nlp__.bluetooth',
#     '__nlp__.bluetooth sound',
#     '__nlp__.blvd',
#     '__nlp__.blvd and',
#     '__nlp__.board',
#     '__nlp__.board games',
#     '__nlp__.board games first',
#     '__nlp__.boardwalk',
#     '__nlp__.boasts',
#     '__nlp__.body',
#     '__nlp__.body soap',
#     '__nlp__.body soap bbq',
#     '__nlp__.body soap clothing',
#     '__nlp__.body soap extra',
#     '__nlp__.body soap hot',
#     '__nlp__.body wash',
#     '__nlp__.book',
#     '__nlp__.booking',
#     '__nlp__.booking br',
#     '__nlp__.booking br br',
#     '__nlp__.books',
#     '__nlp__.books and',
#     '__nlp__.books and toys',
#     ...],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x7f8bfde79880>,
#    'memory_size': 203545241,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True},
#   'RandomForestEntr': {'name': 'RandomForestEntr',
#    'model_type': 'RFModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 6.954784154891968,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.07425093650817871,
#    'val_score': 0.5364077669902912,
#    'hyperparameters': {'n_estimators': 300,
#     'max_leaf_nodes': 15000,
#     'n_jobs': -1,
#     'random_state': 0,
#     'bootstrap': True,
#     'criterion': 'entropy'},
#    'hyperparameters_fit': {'n_estimators': 300},
#    'hyperparameters_nondefault': ['criterion'],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': ['bool', 'int', 'float', 'category'],
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None},
#    'num_features': 5151,
#    'features': ['last_scraped',
#     'host_id',
#     'host_listings_count',
#     'host_total_listings_count',
#     'host_has_profile_pic',
#     'host_identity_verified',
#     'accommodates',
#     'beds',
#     'minimum_nights',
#     'maximum_nights',
#     'minimum_minimum_nights',
#     'maximum_minimum_nights',
#     'minimum_maximum_nights',
#     'maximum_maximum_nights',
#     'minimum_nights_avg_ntm',
#     'maximum_nights_avg_ntm',
#     'has_availability',
#     'availability_30',
#     'availability_60',
#     'availability_90',
#     'availability_365',
#     'number_of_reviews',
#     'number_of_reviews_ltm',
#     'number_of_reviews_l30d',
#     'instant_bookable',
#     'calculated_host_listings_count',
#     'calculated_host_listings_count_entire_homes',
#     'calculated_host_listings_count_private_rooms',
#     'calculated_host_listings_count_shared_rooms',
#     'name',
#     'description',
#     'picture_url',
#     'host_name',
#     'host_is_superhost',
#     'host_verifications',
#     'neighbourhood_cleansed',
#     'neighbourhood_group_cleansed',
#     'property_type',
#     'room_type',
#     'bathrooms_text',
#     'amenities',
#     'location',
#     'host_since',
#     'host_since.year',
#     'host_since.month',
#     'host_since.day',
#     'host_since.dayofweek',
#     'name.char_count',
#     'name.word_count',
#     'name.capital_ratio',
#     'name.lower_ratio',
#     'name.digit_ratio',
#     'name.special_ratio',
#     'name.symbol_count..',
#     'name.symbol_ratio..',
#     'name.symbol_count. ',
#     'name.symbol_ratio. ',
#     'description.char_count',
#     'description.word_count',
#     'description.capital_ratio',
#     'description.lower_ratio',
#     'description.digit_ratio',
#     'description.special_ratio',
#     'description.symbol_count.!',
#     'description.symbol_ratio.!',
#     'description.symbol_count.?',
#     'description.symbol_ratio.?',
#     'description.symbol_count.%',
#     'description.symbol_ratio.%',
#     'description.symbol_count.$',
#     'description.symbol_ratio.$',
#     'description.symbol_count.*',
#     'description.symbol_ratio.*',
#     'description.symbol_count.&',
#     'description.symbol_ratio.&',
#     'description.symbol_count.#',
#     'description.symbol_ratio.#',
#     'description.symbol_count..',
#     'description.symbol_ratio..',
#     'description.symbol_count.:',
#     'description.symbol_ratio.:',
#     'description.symbol_count. ',
#     'description.symbol_ratio. ',
#     'description.symbol_count./',
#     'description.symbol_ratio./',
#     'description.symbol_count.;',
#     'description.symbol_ratio.;',
#     'description.symbol_count.-',
#     'description.symbol_ratio.-',
#     'property_type.char_count',
#     'property_type.word_count',
#     'property_type.capital_ratio',
#     'property_type.lower_ratio',
#     'property_type.special_ratio',
#     'property_type.symbol_ratio. ',
#     'amenities.char_count',
#     'amenities.word_count',
#     'amenities.capital_ratio',
#     'amenities.lower_ratio',
#     'amenities.digit_ratio',
#     'amenities.special_ratio',
#     'amenities.symbol_count.:',
#     'amenities.symbol_ratio.:',
#     'amenities.symbol_count. ',
#     'amenities.symbol_ratio. ',
#     'amenities.symbol_count./',
#     'amenities.symbol_ratio./',
#     'amenities.symbol_count.-',
#     'amenities.symbol_ratio.-',
#     '__nlp__.000',
#     '__nlp__.10',
#     '__nlp__.10 min',
#     '__nlp__.10 minute',
#     '__nlp__.10 minutes',
#     '__nlp__.10 years',
#     '__nlp__.10 years old',
#     '__nlp__.100',
#     '__nlp__.101',
#     '__nlp__.11',
#     '__nlp__.12',
#     '__nlp__.14',
#     '__nlp__.15',
#     '__nlp__.15 min',
#     '__nlp__.15 minutes',
#     '__nlp__.16',
#     '__nlp__.19',
#     '__nlp__.1920',
#     '__nlp__.1st',
#     '__nlp__.20',
#     '__nlp__.20 min',
#     '__nlp__.20 minutes',
#     '__nlp__.2022',
#     '__nlp__.24',
#     '__nlp__.24 hour',
#     '__nlp__.24 hours',
#     '__nlp__.24 hours heated',
#     '__nlp__.25',
#     '__nlp__.2nd',
#     '__nlp__.2nd bedroom',
#     '__nlp__.2nd floor',
#     '__nlp__.30',
#     '__nlp__.30 minutes',
#     '__nlp__.31',
#     '__nlp__.32',
#     '__nlp__.360',
#     '__nlp__.3pm',
#     '__nlp__.3rd',
#     '__nlp__.40',
#     '__nlp__.405',
#     '__nlp__.42',
#     '__nlp__.45',
#     '__nlp__.4k',
#     '__nlp__.50',
#     '__nlp__.50 hdtv',
#     '__nlp__.50 hdtv with',
#     '__nlp__.500',
#     '__nlp__.55',
#     '__nlp__.55 hdtv',
#     '__nlp__.55 hdtv with',
#     '__nlp__.60',
#     '__nlp__.60 hdtv',
#     '__nlp__.60 hdtv with',
#     '__nlp__.65',
#     '__nlp__.65 hdtv',
#     '__nlp__.65 hdtv with',
#     '__nlp__.67',
#     '__nlp__.67 bedrooms',
#     '__nlp__.70',
#     '__nlp__.71',
#     '__nlp__.75',
#     '__nlp__.75 hdtv',
#     '__nlp__.80',
#     '__nlp__.82',
#     '__nlp__.83',
#     '__nlp__.85',
#     '__nlp__.86',
#     '__nlp__.86 bedrooms',
#     '__nlp__.87',
#     '__nlp__.88',
#     '__nlp__.88 bedrooms',
#     '__nlp__.89',
#     '__nlp__.90',
#     '__nlp__.90 bedrooms',
#     '__nlp__.91',
#     '__nlp__.92',
#     '__nlp__.93',
#     '__nlp__.93 bedrooms',
#     '__nlp__.93 bedrooms beds',
#     '__nlp__.94',
#     '__nlp__.94 bedrooms',
#     '__nlp__.95',
#     '__nlp__.96',
#     '__nlp__.97',
#     '__nlp__.98',
#     '__nlp__.99',
#     '__nlp__.abbot',
#     '__nlp__.abbot kinney',
#     '__nlp__.abbott',
#     '__nlp__.able',
#     '__nlp__.able to',
#     '__nlp__.about',
#     '__nlp__.above',
#     '__nlp__.absolutely',
#     '__nlp__.ac',
#     '__nlp__.ac split',
#     '__nlp__.ac unit',
#     '__nlp__.ac unit ceiling',
#     '__nlp__.ac unit free',
#     '__nlp__.access',
#     '__nlp__.access br',
#     '__nlp__.access br entire',
#     '__nlp__.access br guest',
#     '__nlp__.access br guests',
#     '__nlp__.access br the',
#     '__nlp__.access br you',
#     '__nlp__.access hair',
#     '__nlp__.access hangers',
#     '__nlp__.access the',
#     '__nlp__.access to',
#     '__nlp__.access to all',
#     '__nlp__.access to everything',
#     '__nlp__.access to public',
#     '__nlp__.access to the',
#     '__nlp__.access u2013',
#     '__nlp__.accessible',
#     '__nlp__.accommodate',
#     '__nlp__.accommodations',
#     '__nlp__.acre',
#     '__nlp__.across',
#     '__nlp__.across the',
#     '__nlp__.across the street',
#     '__nlp__.activities',
#     '__nlp__.added',
#     '__nlp__.addition',
#     '__nlp__.additional',
#     '__nlp__.address',
#     '__nlp__.address and',
#     '__nlp__.adjacent',
#     '__nlp__.adjacent to',
#     '__nlp__.adults',
#     '__nlp__.adventurers',
#     '__nlp__.after',
#     '__nlp__.ages',
#     '__nlp__.ages years',
#     '__nlp__.aid',
#     '__nlp__.aid kit',
#     '__nlp__.aid kit baking',
#     '__nlp__.aid kit dedicated',
#     '__nlp__.aid kit essentials',
#     '__nlp__.aid kit fire',
#     '__nlp__.aid kit indoor',
#     '__nlp__.aid kit mosquito',
#     '__nlp__.aid kit pets',
#     '__nlp__.aid kit private',
#     '__nlp__.aid kit stainless',
#     '__nlp__.air',
#     '__nlp__.air conditioning',
#     '__nlp__.air conditioning clothing',
#     '__nlp__.air conditioning coffee',
#     '__nlp__.air conditioning fire',
#     '__nlp__.air conditioning hot',
#     '__nlp__.air conditioning kitchen',
#     '__nlp__.air conditioning lock',
#     '__nlp__.air conditioning microwave',
#     '__nlp__.air conditioning outdoor',
#     '__nlp__.air conditioning pack',
#     '__nlp__.air conditioning pool',
#     '__nlp__.air conditioning room',
#     '__nlp__.air conditioning shared',
#     '__nlp__.air conditioning shower',
#     '__nlp__.air conditioning smoke',
#     '__nlp__.air conditioning smoking',
#     '__nlp__.air conditioning tv',
#     '__nlp__.air mattress',
#     '__nlp__.airbnb',
#     '__nlp__.airport',
#     '__nlp__.airy',
#     '__nlp__.al',
#     '__nlp__.alarm',
#     '__nlp__.alarm air',
#     '__nlp__.alarm board',
#     '__nlp__.alarm carbon',
#     '__nlp__.alarm dedicated',
#     '__nlp__.alarm dryer',
#     '__nlp__.alarm essentials',
#     '__nlp__.alarm essentials refrigerator',
#     '__nlp__.alarm fire',
#     '__nlp__.alarm first',
#     '__nlp__.alarm freezer',
#     '__nlp__.alarm freezer dining',
#     '__nlp__.alarm indoor',
#     '__nlp__.alarm iron',
#     '__nlp__.alarm iron air',
#     '__nlp__.alarm iron city',
#     '__nlp__.alarm iron dining',
#     '__nlp__.alarm iron first',
#     '__nlp__.alarm iron freezer',
#     '__nlp__.alarm iron gym',
#     '__nlp__.alarm iron host',
#     '__nlp__.alarm iron microwave',
#     '__nlp__.alarm iron stainless',
#     '__nlp__.alarm outdoor',
#     '__nlp__.alarm pets',
#     '__nlp__.alarm stainless',
#     '__nlp__.alarm valley',
#     '__nlp__.alhambra',
#     '__nlp__.all',
#     '__nlp__.all new',
#     '__nlp__.all of',
#     '__nlp__.all of the',
#     '__nlp__.all that',
#     '__nlp__.all the',
#     '__nlp__.all the amenities',
#     '__nlp__.all the best',
#     '__nlp__.all within',
#     '__nlp__.all year',
#     '__nlp__.all year open',
#     '__nlp__.all your',
#     '__nlp__.allow',
#     '__nlp__.allowed',
#     '__nlp__.allowed backyard',
#     '__nlp__.allowed backyard shampoo',
#     '__nlp__.allowed bathtub',
#     '__nlp__.allowed bathtub bed',
#     '__nlp__.allowed bathtub cleaning',
#     '__nlp__.allowed bathtub lockbox',
#     '__nlp__.allowed bed',
#     '__nlp__.allowed books',
#     '__nlp__.allowed br',
#     '__nlp__.allowed ceiling',
#     '__nlp__.allowed cleaning',
#     '__nlp__.allowed essentials',
#     '__nlp__.allowed essentials conditioner',
#     '__nlp__.allowed essentials refrigerator',
#     '__nlp__.allowed essentials tv',
#     '__nlp__.allowed free',
#     '__nlp__.allowed kitchen',
#     '__nlp__.allowed kitchen wifi',
#     '__nlp__.allowed lockbox',
#     '__nlp__.allowed microwave',
#     '__nlp__.allowed mountain',
#     '__nlp__.allowed refrigerator',
#     '__nlp__.allowed shampoo',
#     '__nlp__.allowed shampoo kitchen',
#     '__nlp__.allowed single',
#     '__nlp__.allowed smoke',
#     '__nlp__.allowed tv',
#     '__nlp__.allowed tv air',
#     '__nlp__.allowed washer',
#     '__nlp__.allowed washer backyard',
#     '__nlp__.allowed washer free',
#     '__nlp__.allowed washer shampoo',
#     '__nlp__.allowed washer single',
#     '__nlp__.allows',
#     '__nlp__.along',
#     '__nlp__.along the',
#     '__nlp__.along with',
#     '__nlp__.also',
#     '__nlp__.also has',
#     '__nlp__.also have',
#     '__nlp__.also offers',
#     '__nlp__.also offers in',
#     '__nlp__.altadena',
#     '__nlp__.always',
#     '__nlp__.always at',
#     '__nlp__.am',
#     '__nlp__.amazing',
#     '__nlp__.amazon',
#     '__nlp__.amazon prime',
#     '__nlp__.amazon prime video',
#     '__nlp__.ambiance',
#     '__nlp__.amenities',
#     '__nlp__.amenities and',
#     '__nlp__.amenities br',
#     '__nlp__.amenities br br',
#     '__nlp__.amenities include',
#     '__nlp__.amenities unique',
#     '__nlp__.amenities you',
#     '__nlp__.ample',
#     '__nlp__.an',
#     '__nlp__.an additional',
#     '__nlp__.an amazing',
#     '__nlp__.an extra',
#     '__nlp__.an office',
#     '__nlp__.an on',
#     '__nlp__.an on site',
#     '__nlp__.an open',
#     '__nlp__.an open floor',
#     '__nlp__.an outdoor',
#     '__nlp__.and',
#     '__nlp__.and 10',
#     '__nlp__.and 10 years',
#     '__nlp__.and air',
#     '__nlp__.and airy',
#     '__nlp__.and all',
#     '__nlp__.and all the',
#     '__nlp__.and an',
#     '__nlp__.and aux',
#     '__nlp__.and back',
#     '__nlp__.and backyard',
#     '__nlp__.and bars',
#     '__nlp__.and bath',
#     '__nlp__.and bathroom',
#     '__nlp__.and bathrooms',
#     '__nlp__.and bbq',
#     '__nlp__.and beautiful',
#     '__nlp__.and blankets',
#     '__nlp__.and blankets bbq',
#     '__nlp__.and blankets beach',
#     '__nlp__.and blankets clothing',
#     '__nlp__.and blankets coffee',
#     '__nlp__.and blankets hot',
#     '__nlp__.and blankets portable',
#     '__nlp__.and blankets safe',
#     '__nlp__.and breakfast',
#     '__nlp__.and bright',
#     '__nlp__.and business',
#     '__nlp__.and centrally',
#     '__nlp__.and clean',
#     '__nlp__.and close',
#     '__nlp__.and closet',
#     '__nlp__.and closet free',
#     '__nlp__.and coffee',
#     '__nlp__.and comfort',
#     '__nlp__.and comfortable',
#     '__nlp__.and convenience',
# ...
#      '__nlp__.and large',
#      '__nlp__.and laundry',
#      '__nlp__.and living',
#      '__nlp__.and living room',
#      '__nlp__.and lots',
#      '__nlp__.and luxurious',
#      '__nlp__.and many',
#      '__nlp__.and modern',
#      '__nlp__.and more',
#      '__nlp__.and more br',
#      '__nlp__.and much',
#      '__nlp__.and much more',
#      '__nlp__.and new',
#      '__nlp__.and one',
#      '__nlp__.and open',
#      '__nlp__.and or',
#      '__nlp__.and other',
#      '__nlp__.and other popular',
#      '__nlp__.and our',
#      '__nlp__.and outdoor',
#      '__nlp__.and parking',
#      '__nlp__.and patio',
#      '__nlp__.and peaceful',
#      '__nlp__.and plenty',
#      '__nlp__.and plenty of',
#      '__nlp__.and pool',
#      '__nlp__.and private',
#      '__nlp__.and queen',
#      '__nlp__.and quiet',
#      '__nlp__.and reading',
#      '__nlp__.and reading material',
#      '__nlp__.and relax',
#      '__nlp__.and relax in',
#      '__nlp__.and relaxation',
#      '__nlp__.and relaxing',
#      '__nlp__.and restaurants',
#      '__nlp__.and restaurants br',
#      '__nlp__.and safe',
#      '__nlp__.and santa',
#      '__nlp__.and santa monica',
#      '__nlp__.and serene',
#      '__nlp__.and shopping',
#      '__nlp__.and shops',
#      '__nlp__.and shower',
#      '__nlp__.and silverware',
#      '__nlp__.and silverware barbecue',
#      '__nlp__.and silverware beach',
#      '__nlp__.and silverware clothing',
#      '__nlp__.and silverware coffee',
#      '__nlp__.and silverware cooking',
#      '__nlp__.and silverware dishwasher',
#      '__nlp__.and silverware keypad',
#      '__nlp__.and silverware pack',
#      '__nlp__.and silverware private',
#      '__nlp__.and spa',
#      '__nlp__.and spacious',
#      '__nlp__.and start',
#      '__nlp__.and start living',
#      '__nlp__.and style',
#      '__nlp__.and stylish',
#      '__nlp__.and the',
#      '__nlp__.and there',
#      '__nlp__.and towels',
#      '__nlp__.and toys',
#      '__nlp__.and toys crib',
#      '__nlp__.and toys for',
#      '__nlp__.and toys hair',
#      '__nlp__.and tranquil',
#      '__nlp__.and two',
#      '__nlp__.and unit',
#      '__nlp__.and unwind',
#      '__nlp__.and very',
#      '__nlp__.and wardrobe',
#      '__nlp__.and we',
#      '__nlp__.and you',
#      '__nlp__.and your',
#      '__nlp__.angeles',
#      '__nlp__.angeles and',
#      '__nlp__.angeles bedroom',
#      '__nlp__.angeles bedroom bed',
#      '__nlp__.angeles bedroom beds',
#      '__nlp__.angeles bedrooms',
#      '__nlp__.angeles bedrooms beds',
#      '__nlp__.angeles br',
#      '__nlp__.angeles br br',
#      '__nlp__.angeles has',
#      '__nlp__.angeles new',
#      '__nlp__.angeles new bedroom',
#      '__nlp__.angeles new bedrooms',
#      '__nlp__.angeles studio',
#      '__nlp__.angeles with',
#      '__nlp__.angeles with this',
#      '__nlp__.another',
#      '__nlp__.any',
#      '__nlp__.any questions',
#      '__nlp__.anyone',
#      '__nlp__.anything',
#      '__nlp__.apartment',
#      '__nlp__.apartment also',
#      '__nlp__.apartment br',
#      '__nlp__.apartment carbon',
#      '__nlp__.apartment has',
#      '__nlp__.apartment in',
#      '__nlp__.apartment in los',
#      '__nlp__.apartment in the',
#      '__nlp__.apartment is',
#      '__nlp__.apartment laundry',
#      '__nlp__.apartment laundry br',
#      '__nlp__.apartment located',
#      '__nlp__.apartment with',
#      '__nlp__.apartment with its',
#      '__nlp__.apartment you',
#      '__nlp__.apartment you ll',
#      '__nlp__.apartments',
#      '__nlp__.apple',
#      '__nlp__.apple tv',
#      '__nlp__.apple tv disney',
#      '__nlp__.appliances',
#      '__nlp__.appliances and',
#      '__nlp__.appliances br',
#      '__nlp__.appointed',
#      '__nlp__.apt',
#      '__nlp__.arcadia',
#      '__nlp__.architectural',
#      '__nlp__.architecture',
#      '__nlp__.are',
#      '__nlp__.are all',
#      '__nlp__.are also',
#      '__nlp__.are available',
#      '__nlp__.are in',
#      '__nlp__.are just',
#      '__nlp__.are located',
#      '__nlp__.are not',
#      '__nlp__.are two',
#      '__nlp__.are welcome',
#      '__nlp__.area',
#      '__nlp__.area and',
#      '__nlp__.area br',
#      '__nlp__.area br br',
#      '__nlp__.area central',
#      '__nlp__.area fire',
#      '__nlp__.area fire extinguisher',
#      '__nlp__.area for',
#      '__nlp__.area gas',
#      '__nlp__.area gas stove',
#      '__nlp__.area hot',
#      '__nlp__.area hot water',
#      '__nlp__.area is',
#      '__nlp__.area kitchen',
#      '__nlp__.area kitchen security',
#      '__nlp__.area kitchen wifi',
#      '__nlp__.area of',
#      '__nlp__.area private',
#      '__nlp__.area room',
#      '__nlp__.area shared',
#      '__nlp__.area shared patio',
#      '__nlp__.area shower',
#      '__nlp__.area tv',
#      '__nlp__.area tv with',
#      '__nlp__.area with',
#      '__nlp__.areas',
#      '__nlp__.around',
#      '__nlp__.around the',
#      '__nlp__.arrival',
#      '__nlp__.art',
#      '__nlp__.arts',
#      '__nlp__.arts district',
#      '__nlp__.as',
#      '__nlp__.as the',
#      '__nlp__.as well',
#      '__nlp__.as well as',
#      '__nlp__.as you',
#      '__nlp__.ask',
#      '__nlp__.assigned',
#      '__nlp__.at',
#      '__nlp__.at home',
#      '__nlp__.at night',
#      '__nlp__.at our',
#      '__nlp__.at the',
#      '__nlp__.at this',
#      '__nlp__.at this centrally',
#      '__nlp__.at this peaceful',
#      '__nlp__.at time',
#      '__nlp__.at your',
#      '__nlp__.atmosphere',
#      '__nlp__.attached',
#      '__nlp__.attractions',
#      '__nlp__.attractions br',
#      '__nlp__.aux',
#      '__nlp__.availability',
#      '__nlp__.available',
#      '__nlp__.available all',
#      '__nlp__.available all year',
#      '__nlp__.available br',
#      '__nlp__.available br br',
#      '__nlp__.available during',
#      '__nlp__.available during stay',
#      '__nlp__.available for',
#      '__nlp__.available to',
#      '__nlp__.available upon',
#      '__nlp__.avalon',
#      '__nlp__.ave',
#      '__nlp__.avenue',
#      '__nlp__.awaits',
#      '__nlp__.away',
#      '__nlp__.away br',
#      '__nlp__.away br br',
#      '__nlp__.away from',
#      '__nlp__.away from home',
#      '__nlp__.away from rodeo',
#      '__nlp__.away from the',
#      '__nlp__.baby',
#      '__nlp__.baby bath',
#      '__nlp__.baby monitor',
#      '__nlp__.baby safety',
#      '__nlp__.babysitter',
#      '__nlp__.babysitter recommendations',
#      '__nlp__.babysitter recommendations central',
#      '__nlp__.back',
#      '__nlp__.back and',
#      '__nlp__.back and relax',
#      '__nlp__.back of',
#      '__nlp__.back patio',
#      '__nlp__.back yard',
#      '__nlp__.backyard',
#      '__nlp__.backyard and',
#      '__nlp__.backyard br',
#      '__nlp__.backyard is',
#      '__nlp__.backyard kitchen',
#      '__nlp__.backyard kitchen wifi',
#      '__nlp__.backyard shampoo',
#      '__nlp__.backyard shampoo kitchen',
#      '__nlp__.backyard u2013',
#      '__nlp__.backyard u2013 fully',
#      '__nlp__.backyard u2013 not',
#      '__nlp__.backyard with',
#      '__nlp__.baking',
#      '__nlp__.baking sheet',
#      '__nlp__.baking sheet essentials',
#      '__nlp__.baking sheet mountain',
#      '__nlp__.baking sheet pets',
#      '__nlp__.baking sheet record',
#      '__nlp__.baking sheet sun',
#      '__nlp__.balconies',
#      '__nlp__.balcony',
#      '__nlp__.balcony ac',
#      '__nlp__.balcony baking',
#      '__nlp__.balcony br',
#      '__nlp__.balcony central',
#      '__nlp__.balcony central air',
#      '__nlp__.balcony children',
#      '__nlp__.balcony dishes',
#      '__nlp__.balcony dishwasher',
#      '__nlp__.balcony dishwasher coffee',
#      '__nlp__.balcony essentials',
#      '__nlp__.balcony essentials conditioner',
#      '__nlp__.balcony essentials refrigerator',
#      '__nlp__.balcony free',
#      '__nlp__.balcony free parking',
#      '__nlp__.balcony pets',
#      '__nlp__.balcony shared',
#      '__nlp__.balcony shower',
#      '__nlp__.balcony sun',
#      '__nlp__.balcony wine',
#      '__nlp__.balcony with',
#      '__nlp__.bar',
#      '__nlp__.barbecue',
#      '__nlp__.barbecue utensils',
#      '__nlp__.barbecue utensils dishes',
#      '__nlp__.barbecue utensils dishwasher',
#      '__nlp__.bars',
#      '__nlp__.bars and',
#      '__nlp__.base',
#      '__nlp__.basic',
#      '__nlp__.basics',
#      '__nlp__.basics beach',
#      '__nlp__.basics clothing',
#      '__nlp__.basics free',
#      '__nlp__.basics free washer',
#      '__nlp__.basics hangers',
#      '__nlp__.basics hangers blender',
#      '__nlp__.basics hangers coffee',
#      '__nlp__.basics hangers elevator',
#      '__nlp__.basics hangers hair',
#      '__nlp__.basics hangers paid',
#      '__nlp__.basics hangers private',
#      '__nlp__.basics hangers self',
#      '__nlp__.basics hangers tv',
#      '__nlp__.basics keypad',
#      '__nlp__.basics keypad free',
#      '__nlp__.basics keypad hangers',
#      '__nlp__.basics pack',
#      '__nlp__.basics ping',
#      '__nlp__.basics private',
#      '__nlp__.basics private backyard',
#      '__nlp__.basics self',
#      '__nlp__.basics waterfront',
#      '__nlp__.basketball',
#      '__nlp__.bath',
#      '__nlp__.bath and',
#      '__nlp__.bath br',
#      '__nlp__.bath enjoy',
#      '__nlp__.bath home',
#      '__nlp__.bath located',
#      '__nlp__.bath private',
#      '__nlp__.bath the',
#      '__nlp__.bath this',
#      '__nlp__.bath this is',
#      '__nlp__.bath welcome',
#      '__nlp__.bath welcome to',
#      '__nlp__.bath with',
#      '__nlp__.bathroom',
#      '__nlp__.bathroom and',
#      '__nlp__.bathroom br',
#      '__nlp__.bathroom br br',
#      '__nlp__.bathroom has',
#      '__nlp__.bathroom home',
#      '__nlp__.bathroom is',
#      '__nlp__.bathroom the',
#      '__nlp__.bathroom with',
#      '__nlp__.bathrooms',
#      '__nlp__.bathrooms and',
#      '__nlp__.bathrooms br',
#      '__nlp__.baths',
#      '__nlp__.baths beautiful',
#      '__nlp__.baths enjoy',
#      '__nlp__.baths entire',
#      '__nlp__.baths located',
#      '__nlp__.baths our',
#      '__nlp__.baths relax',
#      '__nlp__.baths the',
#      '__nlp__.baths this',
#      '__nlp__.baths welcome',
#      '__nlp__.baths welcome to',
#      '__nlp__.bathtub',
#      '__nlp__.bathtub bed',
#      '__nlp__.bathtub cleaning',
#      '__nlp__.bathtub cleaning products',
#      '__nlp__.bathtub heating',
#      '__nlp__.bathtub heating split',
#      '__nlp__.bathtub lockbox',
#      '__nlp__.bathtub lockbox bed',
#      '__nlp__.bathtub lockbox cleaning',
#      '__nlp__.bathtub luggage',
#      '__nlp__.bathtub smoke',
#      '__nlp__.bay',
#      '__nlp__.bbq',
#      '__nlp__.bbq and',
#      '__nlp__.bbq area',
#      '__nlp__.bbq area br',
#      '__nlp__.bbq grill',
#      '__nlp__.bbq grill charcoal',
#      '__nlp__.bbq grill cleaning',
#      '__nlp__.bbq grill gas',
#      '__nlp__.bbq grill hot',
#      '__nlp__.bbq grill private',
#      '__nlp__.bbq grill smart',
#      '__nlp__.bbq grill washer',
#      '__nlp__.bbq grill wifi',
#      '__nlp__.be',
#      '__nlp__.be close',
#      '__nlp__.be given',
#      '__nlp__.be greeted',
#      '__nlp__.be used',
#      '__nlp__.beach',
#      '__nlp__.beach access',
#      '__nlp__.beach and',
#      '__nlp__.beach bedrooms',
#      '__nlp__.beach bedrooms beds',
#      '__nlp__.beach br',
#      '__nlp__.beach br br',
#      '__nlp__.beach essentials',
#      '__nlp__.beach essentials free',
#      '__nlp__.beach essentials washer',
#      '__nlp__.beach house',
#      '__nlp__.beach the',
#      '__nlp__.beach view',
#      '__nlp__.beach view ocean',
#      '__nlp__.beaches',
#      '__nlp__.beaches and',
#      '__nlp__.beachfront',
#      '__nlp__.beautiful',
#      '__nlp__.beautiful and',
#      '__nlp__.beautiful home',
#      '__nlp__.beautifully',
#      '__nlp__.beautifully designed',
#      '__nlp__.beauty',
#      '__nlp__.because',
#      '__nlp__.because of',
#      '__nlp__.bed',
#      '__nlp__.bed and',
#      '__nlp__.bed and breakfast',
#      '__nlp__.bed bath',
#      '__nlp__.bed bath this',
#      '__nlp__.bed bath welcome',
#      '__nlp__.bed baths',
#      '__nlp__.bed br',
#      '__nlp__.bed br br',
#      '__nlp__.bed in',
#      '__nlp__.bed in the',
#      '__nlp__.bed linens',
#      '__nlp__.bed linens indoor',
#      '__nlp__.bed linens smoke',
#      '__nlp__.bed private',
#      '__nlp__.bed private bath',
#      '__nlp__.bed shared',
#      '__nlp__.bed shared bath',
#      '__nlp__.bed shared baths',
#      '__nlp__.bed the',
#      '__nlp__.bed with',
#      '__nlp__.bedding',
#      '__nlp__.bedroom',
#      '__nlp__.bedroom and',
#      '__nlp__.bedroom and bathroom',
#      '__nlp__.bedroom apartment',
#      '__nlp__.bedroom apartment with',
#      '__nlp__.bedroom bath',
#      '__nlp__.bedroom bathroom',
#      '__nlp__.bedroom bathroom home',
#      '__nlp__.bedroom bed',
#      '__nlp__.bedroom bed bath',
#      '__nlp__.bedroom bed baths',
#      '__nlp__.bedroom bed private',
#      '__nlp__.bedroom bed shared',
#      '__nlp__.bedroom beds',
#      '__nlp__.bedroom beds bath',
#      '__nlp__.bedroom br',
#      '__nlp__.bedroom door',
#      '__nlp__.bedroom door microwave',
#      '__nlp__.bedroom has',
#      '__nlp__.bedroom has queen',
#      '__nlp__.bedroom home',
#      '__nlp__.bedroom house',
#      '__nlp__.bedroom is',
#      '__nlp__.bedroom one',
#      '__nlp__.bedroom queen',
#      '__nlp__.bedroom queen bed',
#      '__nlp__.bedroom suite',
#      '__nlp__.bedroom with',
#      '__nlp__.bedroom with queen',
#      '__nlp__.bedrooms',
#      '__nlp__.bedrooms and',
#      '__nlp__.bedrooms and bathrooms',
#      '__nlp__.bedrooms are',
#      '__nlp__.bedrooms bathrooms',
#      '__nlp__.bedrooms baths',
#      '__nlp__.bedrooms bed',
#      '__nlp__.bedrooms beds',
#      '__nlp__.bedrooms beds bath',
#      '__nlp__.bedrooms beds baths',
#      '__nlp__.bedrooms br',
#      '__nlp__.bedrooms have',
#      '__nlp__.bedrooms with',
#      '__nlp__.beds',
#      '__nlp__.beds and',
#      '__nlp__.beds bath',
#      '__nlp__.beds bath enjoy',
#      '__nlp__.beds bath this',
#      '__nlp__.beds bath welcome',
#      '__nlp__.beds baths',
#      '__nlp__.beds baths beautiful',
#      '__nlp__.beds baths enjoy',
#      '__nlp__.beds baths our',
#      '__nlp__.beds baths relax',
#      '__nlp__.beds baths the',
#      '__nlp__.beds baths this',
#      '__nlp__.beds baths welcome',
#      '__nlp__.beds br',
#      '__nlp__.beds private',
#      '__nlp__.beds private bath',
#      '__nlp__.beds shared',
#      '__nlp__.been',
#      '__nlp__.before',
#      '__nlp__.before booking',
#      '__nlp__.behind',
#      '__nlp__.being',
#      '__nlp__.belmont',
#      '__nlp__.below',
#      '__nlp__.best',
#      '__nlp__.best location',
#      '__nlp__.best of',
#      '__nlp__.best restaurants',
#      '__nlp__.better',
#      '__nlp__.between',
#      '__nlp__.beverly',
#      '__nlp__.beverly hills',
#      '__nlp__.beverly hills and',
#      '__nlp__.beverly hills bedroom',
#      '__nlp__.beverly hills bedrooms',
#      '__nlp__.beverly hills new',
#      '__nlp__.bidet',
#      '__nlp__.bidet dishes',
#      '__nlp__.bidet ethernet',
#      '__nlp__.big',
#      '__nlp__.bike',
#      '__nlp__.bikes',
#      '__nlp__.blankets',
#      '__nlp__.blankets safe hot',
#      '__nlp__.blend',
#      '__nlp__.blend of',
#      '__nlp__.blender',
#      '__nlp__.blender coffee',
#      '__nlp__.blender coffee outdoor',
#      '__nlp__.blender coffee self',
#      '__nlp__.blender coffee tv',
#      '__nlp__.blender self',
#      '__nlp__.block',
#      '__nlp__.block away',
#      '__nlp__.block from',
#      '__nlp__.blocks',
#      '__nlp__.blocks away',
#      '__nlp__.blocks from',
#      '__nlp__.blocks from the',
#      '__nlp__.blocks to',
#      '__nlp__.blue',
#      '__nlp__.blueground',
#      '__nlp__.blueground apartment',
#      '__nlp__.bluetooth',
#      '__nlp__.bluetooth sound',
#      '__nlp__.blvd',
#      '__nlp__.blvd and',
#      '__nlp__.board',
#      '__nlp__.board games',
#      '__nlp__.board games first',
#      '__nlp__.boardwalk',
#      '__nlp__.boasts',
#      '__nlp__.body',
#      '__nlp__.body soap',
#      '__nlp__.body soap bbq',
#      '__nlp__.body soap clothing',
#      '__nlp__.body soap extra',
#      '__nlp__.body soap hot',
#      '__nlp__.body wash',
#      '__nlp__.book',
#      '__nlp__.booking',
#      '__nlp__.booking br',
#      '__nlp__.booking br br',
#      '__nlp__.books',
#      '__nlp__.books and',
#      '__nlp__.books and toys',
#      ...],
#     'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x7f8a906c2730>,
#     'memory_size': 191763,
#     'compile_time': None,
#     'is_initialized': True,
#     'is_fit': False,
#     'is_valid': False,
#     'can_infer': False},
#    'total_time': 1.2015628814697266}}}
